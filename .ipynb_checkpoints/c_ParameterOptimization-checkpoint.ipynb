# %% [markdown]
# ## [1] Import Libraries

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sklearn
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, PredefinedSplit
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn import metrics
import rasterio as rio
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## [2] Set Up Masks
#
# This sections creates masks for the MEASURES 2012-2013 mosaic no data regions, so that we can mask these out of the strain rate data which would otherwise have strange edge effects where the velocity data stops existing.

# %%
# Directories with velocities for training areas on the west coast of Greenland
vel_file_w = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\Velocity\\greenland_vel_mosaic500_2012_2013_vx_training.tif"
vel_file_e = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\Velocity\\greenland_vel_mosaic500_2012_2013_vx_NE.tif"

# Load the M12 velocity file for the west coast of Greenland and generate a mask to remove areas where the velocity data is not valid
dataset = rio.open(vel_file_w)
M12_velocity = dataset.read(1)
dataset.close()
vel_mask_w = np.zeros(M12_velocity.shape)
for i in range(0,vel_mask_w.shape[0]):
    for j in range(0,vel_mask_w.shape[1]):
        if M12_velocity[i,j] != -2e9:
            vel_mask_w[i,j] = 1.

# Load the M12 velocity file for the east coast of Greenland and generate a mask to remove areas where the velocity data is not valid
dataset = rio.open(vel_file_e)
M12_velocity = dataset.read(1)
dataset.close()
vel_mask_e = np.zeros(M12_velocity.shape)
for i in range(0,vel_mask_e.shape[0]):
    for j in range(0,vel_mask_e.shape[1]):
        if M12_velocity[i,j] != -2e9:
            vel_mask_e[i,j] = 1.

# Plot velocity masks for a sanity check
fig, (ax1, ax2) = plt.subplots(1,2,layout="constrained")
im = ax1.imshow(vel_mask_w, cmap='Greys')
ax2.imshow(vel_mask_e, cmap='Greys')
cbar = fig.colorbar(im, location='bottom')
plt.show()

# %% [markdown]
# ## [3] Run the Parameter Optimization

# %%
# Directories with the strain rates
strain_dir_w = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\StrainRate\\"
strain_dir_e = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\StrainRateNE\\"
# Directory with the surface temperatures
temp_dir = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\RACMOTraining\\"
# Directory with the crevasse/no crevasse observations
crev_dir = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\RevisedTrainingData\\"
# Directory with the boundaries of the test data that we will withold from training
test_dir =  "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\TestSet\\"

# List of strain map experiment names
strain_experiments = ["Exp1", "Exp2", "Exp3", "Exp4", "Exp5", "Exp6", "Exp7", 
                      "Exp8", "Exp9", "Exp10", "Exp11", "Exp12", "Exp13", "Exp14", 
                      "Exp15", "Exp16", "Exp17", "Exp18", "Exp19", "Exp20", "Exp21",
                      "Exp22", "Exp23", "Exp24", "Exp25", "Exp26", "Exp27", "Exp28"]
# List of velocity sources to test
velocity_maps = ["MAvg", "M12", "ILAvg"]
# List of temperature average time periods to test
temp_maps = ["Decadal", "Annual", "DJF", "JJA"]

# Uncomment and edit to generate results for a single experiment, instead of the entire optimization ensemble
#strain_experiments = ["Exp18"]
#velocity_maps = ["MAvg"]
#temp_maps = ["Annual"]

# Define the crevasse observations to use for training
crev_map = "MapA"    # other option if "MapB"

# Cuffey and Patterson Constants for Ice Viscosity Model
A_star = 3.5e-25        # Pa^-3s^-1
T_start = 263.0         # K
R = 8.314               # J mol^-1 K^-1
Qc = 60e3               # J mol^-1
Qc2 = 115e3             # J mol^-1
n = 3.

f1_results = np.zeros((len(velocity_maps),len(strain_experiments),len(temp_maps)))           # Save model F1 score
tp_results = np.zeros((len(velocity_maps),len(strain_experiments),len(temp_maps)))           # Save model true positives
fp_results = np.zeros((len(velocity_maps),len(strain_experiments),len(temp_maps)))           # Save model false positives
tn_results = np.zeros((len(velocity_maps),len(strain_experiments),len(temp_maps)))           # Save model true negatives
fn_results = np.zeros((len(velocity_maps),len(strain_experiments),len(temp_maps)))           # Save model false negatives
tensile_strength = np.zeros((len(velocity_maps),len(strain_experiments),len(temp_maps)))     # Save model estimated tensile strength
for i in velocity_maps:
    for j in strain_experiments:
        # Set file locations for the strain rate for the west coast
        eXX_file_w = strain_dir_w+j+"_eXX_"+i+".tif"
        eYY_file_w = strain_dir_w+j+"_eYY_"+i+".tif"
        eXY_file_w = strain_dir_w+j+"_eXY_"+i+".tif"

        # Read in all three components of the strain rate for the west coast
        dataset = rio.open(eXX_file_w)
        eXX_w = dataset.read(1)
        dataset.close()
        dataset = rio.open(eYY_file_w)
        eYY_w = dataset.read(1)
        dataset.close()
        dataset = rio.open(eXY_file_w)
        eXY_w = dataset.read(1)
        dataset.close()

        # Set file locations for the strain rate for the east coast
        eXX_file_e = strain_dir_e+j+"_eXX_"+i+".tif"
        eYY_file_e = strain_dir_e+j+"_eYY_"+i+".tif"
        eXY_file_e = strain_dir_e+j+"_eXY_"+i+".tif"

        # Read in all three components of the strain rate for the east coast
        dataset = rio.open(eXX_file_e)
        eXX_e = dataset.read(1)
        dataset.close()
        dataset = rio.open(eYY_file_e)
        eYY_e = dataset.read(1)
        dataset.close()
        dataset = rio.open(eXY_file_e)
        eXY_e = dataset.read(1)
        dataset.close()

        # Mask out regions of no data in the 2012-2013 strain rate maps
        if i == "M12":
            eXX_w = eXX_w*vel_mask_w
            eYY_w = eYY_w*vel_mask_w
            eXY_w = eXY_w*vel_mask_w
            eXX_e = eXX_e*vel_mask_e
            eYY_e = eYY_e*vel_mask_e
            eXY_e = eXY_e*vel_mask_e

        for k in temp_maps:
            # Find the desired temperature field, crevasse observations, and test set witholding masks
            # at the appropriate resolution to match the strain rate data
            if i == "MAvg":
                temp_file_w = temp_dir+"Clip_RACMO"+k+"_250m.tif"
                temp_file_e = temp_dir+"NE_RACMO"+k+"_250m.tif"
                crev_file_w = crev_dir+"CrevasseMask_250m_"+crev_map+".tif"
                crev_file_e = crev_dir+"NE_CrevasseMask_250m_"+crev_map+".tif"
                nocrev_file_w = crev_dir+"NoCrevasseMask_250m_"+crev_map+".tif"
                nocrev_file_e = crev_dir+"NE_NoCrevasseMask_250m_"+crev_map+".tif"
                test_file_e = test_dir+"NE_TestSet_250m.tif"
                test_file_w = test_dir+"W_TestSet_250m.tif"
            elif i == "M12":
                temp_file_w = temp_dir+"Clip_RACMO"+k+"_500m.tif"
                temp_file_e = temp_dir+"NE_RACMO"+k+"_500m.tif"
                crev_file_w = crev_dir+"CrevasseMask_500m_"+crev_map+".tif"
                crev_file_e = crev_dir+"NE_CrevasseMask_500m_"+crev_map+".tif"
                nocrev_file_w = crev_dir+"NoCrevasseMask_500m_"+crev_map+".tif"
                nocrev_file_e = crev_dir+"NE_NoCrevasseMask_500m_"+crev_map+".tif"
                test_file_e = test_dir+"NE_TestSet_500m.tif"
                test_file_w = test_dir+"W_TestSet_500m.tif"
            elif i == "ILAvg":
                temp_file_w = temp_dir+"Clip_RACMO"+k+"_240m.tif"
                temp_file_e = temp_dir+"NE_RACMO"+k+"_240m.tif"
                crev_file_w = crev_dir+"CrevasseMask_240m_"+crev_map+".tif"
                crev_file_e = crev_dir+"NE_CrevasseMask_240m_"+crev_map+".tif"
                nocrev_file_w = crev_dir+"NoCrevasseMask_240m_"+crev_map+".tif"
                nocrev_file_e = crev_dir+"NE_NoCrevasseMask_240m_"+crev_map+".tif"
                test_file_e = test_dir+"NE_TestSet_240m.tif"
                test_file_w = test_dir+"W_TestSet_240m.tif"

            # Load data for the west coast temperature field
            dataset = rio.open(temp_file_w)
            temp_w = dataset.read(1)
            dataset.close()
            # Load crevasse mask for west coast
            dataset = rio.open(crev_file_w)
            crevasses_w = dataset.read(1)
            dataset.close()
            # Load no crevasse mask for west coast
            dataset = rio.open(nocrev_file_w)
            no_crevasses_w = dataset.read(1)
            dataset.close()
            # Load test set for west coast
            dataset = rio.open(test_file_w)
            test_w = dataset.read(1)
            dataset.close()

            # Load data for the east coast temperature field
            dataset = rio.open(temp_file_e)
            temp_e = dataset.read(1)
            dataset.close()
            # Load crevasse mask for east coast
            dataset = rio.open(crev_file_e)
            crevasses_e = dataset.read(1)
            dataset.close()
            # Load no crevasse mask for east coast
            dataset = rio.open(nocrev_file_e)
            no_crevasses_e = dataset.read(1)
            dataset.close()
             # Load test set for east coast
            dataset = rio.open(test_file_e)
            test_e = dataset.read(1)
            dataset.close()

            # Flatten data from a 2D map into a 1D vector for all datasets, then merge data from east and west training areas 
            # into a single vector for each variable
            crevasses_w = np.matrix.flatten(crevasses_w.astype("float64"))
            crevasses_e = np.matrix.flatten(crevasses_e.astype("float64"))
            crevasses = np.concatenate((crevasses_w, crevasses_e), axis=0)
            no_crevasses_w = np.matrix.flatten(no_crevasses_w.astype("float64"))
            no_crevasses_e = np.matrix.flatten(no_crevasses_e.astype("float64"))
            no_crevasses = np.concatenate((no_crevasses_w, no_crevasses_e), axis=0)
            test_w = np.matrix.flatten(test_w.astype("float64"))
            test_e = np.matrix.flatten(test_e.astype("float64"))
            test = np.concatenate((test_w, test_e), axis=0)

            # Combine flattened strain rate matrices for both regions (east and west)
            eXX_comb = np.concatenate((np.matrix.flatten(eXX_w), np.matrix.flatten(eXX_e)), axis=0)
            eXY_comb = np.concatenate((np.matrix.flatten(eXY_w), np.matrix.flatten(eXY_e)), axis=0)
            eYY_comb = np.concatenate((np.matrix.flatten(eYY_w), np.matrix.flatten(eYY_e)), axis=0)

            # Combine flattened temperature information for both regions (east and west)
            temp_comb = np.concatenate((np.matrix.flatten(temp_w), np.matrix.flatten(temp_e)), axis=0)

            # Extract strain rates for each crevassed or uncrevassed data point
            eXX_crev = eXX_comb[crevasses == 1]
            eXX_nocrev = eXX_comb[no_crevasses == 1]
            eXY_crev = eXY_comb[crevasses == 1]
            eXY_nocrev = eXY_comb[no_crevasses == 1]
            eYY_crev = eYY_comb[crevasses == 1]
            eYY_nocrev = eYY_comb[no_crevasses == 1]

            # Extract temperatures for each crevassed or uncrevassed data point
            temp_crev = temp_comb[crevasses == 1]
            temp_nocrev = temp_comb[no_crevasses == 1]

            # Extract test set for crevassed and uncrevassed regions
            test_crev = test[crevasses == 1]
            test_nocrev = test[no_crevasses == 1]

            # Merge into a single vectors for all variables of interest
            eXX = np.concatenate((eXX_crev, eXX_nocrev), axis=0)
            eXY = np.concatenate((eXY_crev, eXY_nocrev), axis=0)
            eYY = np.concatenate((eYY_crev, eYY_nocrev), axis=0)
            temp = np.concatenate((temp_crev,  temp_nocrev), axis=0)
            test_set = np.concatenate((test_crev,  test_nocrev), axis=0)

            # Convert temperature field to degrees Kelvin
            temp = temp + 273.15

            # Calculate creep coefficient with temperature dependence of activation energy on west coast
            A = np.zeros(temp.shape)
            for p in range(0,temp.shape[0]):
                if temp[p] > 273.15:
                    temp[p] = 273.15
                    A[p] = A_star*np.exp((-Qc2/R)*((1/temp[p]) - (1/T_start)))
                elif temp[p] > 263.0:
                    A[p] = A_star*np.exp((-Qc2/R)*((1/temp[p]) - (1/T_start)))
                else:
                    A[p] = A_star*np.exp((-Qc/R)*((1/temp[p]) - (1/T_start)))

            # Convert strain rates from 1/yr to 1/s
            eXX_s = eXX*(1/(60*60*24*365))
            eXY_s = eXY*(1/(60*60*24*365))
            eYY_s = eYY*(1/(60*60*24*365))

            #Calculate effective stress
            eE = np.sqrt(0.5*(eXX_s**2 + eYY_s**2 + (-eXX_s - eYY_s)**2) + eXY_s**2)

            # Calculate deviatoric stress at surface
            tau_xx = (A**(-1/n))*(eE**((1-n)/n))*eXX_s
            tau_yy = (A**(-1/n))*(eE**((1-n)/n))*eYY_s
            tau_xy = (A**(-1/n))*(eE**((1-n)/n))*eXY_s 

            # Calculate full Cauchy stress at surface
            sigma_xx = 2.*tau_xx + tau_yy
            sigma_yy = 2.*tau_yy + tau_xx

            # Calculate principal stresses
            sigma1 = 0.5*(sigma_xx + sigma_yy) + np.sqrt((0.5*(sigma_xx - sigma_yy))**2 + tau_xy**2)
            sigma2 = 0.5*(sigma_xx + sigma_yy) - np.sqrt((0.5*(sigma_xx - sigma_yy))**2 + tau_xy**2)

            # Von Mises Stress over whole area of interest
            sigmaV = np.sqrt(sigma1**2 - sigma1*sigma2 + sigma2**2)

            # Make the label set (1 = crevasse observed, 0 - no crevasses observed)
            label = np.concatenate((np.ones(temp_crev.shape), np.zeros(temp_nocrev.shape)), axis=0)

            # Remove regions of pure compression, because we will automatically predict no fracture there
            stress = sigmaV[sigma1 > 0.]
            test_set = test_set[sigma1 > 0.]
            compression_label = label[sigma1 <= 0.]
            label = label[sigma1 > 0.]
            
            # Clean up edge case problems for the M12 data with a bunch of gaps
            if i == "M12":
                test_set = test_set[stress < 500000.]
                label = label[stress < 500000.]
                stress = stress[stress < 500000.]

            # Test-train split, using the predefined test areas (test_set[i] = 1 if reserved for testing, otherwise 0)
            stress_train,stress_test,label_train,label_test=train_test_split(stress.reshape(-1,1),label,stratify=test_set)

            # Instantiate a logistic regression model object to be trained with balanced class weights because of our class imbalance
            regress = LogisticRegression(class_weight="balanced")
            # Train model
            regress.fit(stress_train,label_train)

            a = velocity_maps.index(i)
            b = strain_experiments.index(j)
            c = temp_maps.index(k)

            print(i,"-",j,"-",k)

            # Predict the probability of fracture on the training set
            prob = regress.predict_proba(stress_train)
            # Calculate recall and precision for a range of decision thresholds
            precision, recall, thresholds = metrics.precision_recall_curve(label_train, prob[:,1])
            # convert to f score
            fscore = (2 * precision * recall) / (precision + recall)
            fscore[np.isnan(fscore)] = 0
            # locate the index of the largest f score
            ix = np.argmax(fscore)
            print('Best Threshold=%f' % (thresholds[ix]))

            # Calculate crevasse predictions on test set with optimized discrimination threshold
            prob = regress.predict_proba(stress_test)
            y_hat = np.zeros(prob[:,1].shape)
            y_hat[prob[:,1] >= thresholds[ix]] = 1
            # Reincorporate regions of pure compression which we automatically assign to be no crevasse
            y_hat = np.concatenate((y_hat, np.zeros(compression_label.shape)), axis=0)
            y_test = np.concatenate((label_test, compression_label), axis=0)
            # Calculate final model f1 score on all test set predictions
            fscore = metrics.f1_score(y_test, y_hat, average="weighted")
            tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_hat).ravel()
            print('F-Score=%.3f' % (fscore))

            # Save the f1 score
            f1_results[a,b,c] = fscore
            tp_results[a,b,c] = tp
            fp_results[a,b,c] = fp
            fn_results[a,b,c] = fn
            tn_results[a,b,c] = tn

            # Calculate the estimated tensile strength, save it, and print to the screen
            axis = np.arange(20000,250000,1).reshape(-1,1)
            probability = regress.predict_proba(axis)
            ind = np.argmin(np.abs(probability[:,1] - thresholds[ix]))
            tensile_strength[a,b,c] = axis[ind,0]
            print("Tensile Strength: "+str(axis[ind,0]/1000.)+" kPa")
# Out:
# MAvg - Exp1 - Decadal
# Best Threshold=0.384449
# F-Score=0.823
# Tensile Strength: 119.191 kPa
# MAvg - Exp1 - Annual
# Best Threshold=0.379407
# F-Score=0.825
# Tensile Strength: 121.5 kPa
# MAvg - Exp1 - DJF
# Best Threshold=0.382006
# F-Score=0.827
# Tensile Strength: 181.033 kPa
# MAvg - Exp1 - JJA
# Best Threshold=0.369811
# F-Score=0.822
# Tensile Strength: 62.782 kPa
# MAvg - Exp2 - Decadal
# Best Threshold=0.401326
# F-Score=0.850
# Tensile Strength: 114.332 kPa
# MAvg - Exp2 - Annual
# Best Threshold=0.375251
# F-Score=0.852
# Tensile Strength: 114.876 kPa
# MAvg - Exp2 - DJF
# Best Threshold=0.375226
# F-Score=0.854
# Tensile Strength: 171.081 kPa
# MAvg - Exp2 - JJA
# Best Threshold=0.371990
# F-Score=0.851
# Tensile Strength: 59.601 kPa
# MAvg - Exp3 - Decadal
# Best Threshold=0.368740
# F-Score=0.854
# Tensile Strength: 108.334 kPa
# MAvg - Exp3 - Annual
# Best Threshold=0.342573
# F-Score=0.852
# Tensile Strength: 108.665 kPa
# MAvg - Exp3 - DJF
# Best Threshold=0.356916
# F-Score=0.855
# Tensile Strength: 163.753 kPa
# MAvg - Exp3 - JJA
# Best Threshold=0.376781
# F-Score=0.852
# Tensile Strength: 57.963 kPa
# MAvg - Exp4 - Decadal
# Best Threshold=0.356990
# F-Score=0.833
# Tensile Strength: 104.862 kPa
# MAvg - Exp4 - Annual
# Best Threshold=0.357478
# F-Score=0.836
# Tensile Strength: 107.296 kPa
# MAvg - Exp4 - DJF
# Best Threshold=0.342863
# F-Score=0.841
# Tensile Strength: 157.965 kPa
# MAvg - Exp4 - JJA
# Best Threshold=0.363757
# F-Score=0.838
# Tensile Strength: 56.126 kPa
# MAvg - Exp5 - Decadal
# Best Threshold=0.397507
# F-Score=0.818
# Tensile Strength: 106.503 kPa
# MAvg - Exp5 - Annual
# Best Threshold=0.389836
# F-Score=0.822
# Tensile Strength: 108.346 kPa
# MAvg - Exp5 - DJF
# Best Threshold=0.368448
# F-Score=0.822
# Tensile Strength: 158.448 kPa
# MAvg - Exp5 - JJA
# Best Threshold=0.374199
# F-Score=0.819
# Tensile Strength: 55.528 kPa
# MAvg - Exp6 - Decadal
# Best Threshold=0.400738
# F-Score=0.807
# Tensile Strength: 105.255 kPa
# MAvg - Exp6 - Annual
# Best Threshold=0.395155
# F-Score=0.809
# Tensile Strength: 107.206 kPa
# MAvg - Exp6 - DJF
# Best Threshold=0.385542
# F-Score=0.810
# Tensile Strength: 158.513 kPa
# MAvg - Exp6 - JJA
# Best Threshold=0.386839
# F-Score=0.808
# Tensile Strength: 55.244 kPa
# MAvg - Exp7 - Decadal
# Best Threshold=0.436242
# F-Score=0.796
# Tensile Strength: 107.246 kPa
# MAvg - Exp7 - Annual
# Best Threshold=0.399758
# F-Score=0.794
# Tensile Strength: 106.127 kPa
# MAvg - Exp7 - DJF
# Best Threshold=0.401714
# F-Score=0.794
# Tensile Strength: 158.594 kPa
# MAvg - Exp7 - JJA
# Best Threshold=0.383651
# F-Score=0.789
# Tensile Strength: 54.334 kPa
# MAvg - Exp8 - Decadal
# Best Threshold=0.390628
# F-Score=0.817
# Tensile Strength: 120.719 kPa
# MAvg - Exp8 - Annual
# Best Threshold=0.401963
# F-Score=0.819
# Tensile Strength: 124.384 kPa
# MAvg - Exp8 - DJF
# Best Threshold=0.386596
# F-Score=0.820
# Tensile Strength: 183.517 kPa
# MAvg - Exp8 - JJA
# Best Threshold=0.383035
# F-Score=0.817
# Tensile Strength: 63.87 kPa
# MAvg - Exp9 - Decadal
# Best Threshold=0.376270
# F-Score=0.849
# Tensile Strength: 113.33 kPa
# MAvg - Exp9 - Annual
# Best Threshold=0.373734
# F-Score=0.851
# Tensile Strength: 115.515 kPa
# MAvg - Exp9 - DJF
# Best Threshold=0.373032
# F-Score=0.850
# Tensile Strength: 172.285 kPa
# MAvg - Exp9 - JJA
# Best Threshold=0.392136
# F-Score=0.848
# Tensile Strength: 60.864 kPa
# MAvg - Exp10 - Decadal
# Best Threshold=0.384839
# F-Score=0.858
# Tensile Strength: 110.352 kPa
# MAvg - Exp10 - Annual
# Best Threshold=0.359955
# F-Score=0.857
# Tensile Strength: 111.033 kPa
# MAvg - Exp10 - DJF
# Best Threshold=0.363682
# F-Score=0.859
# Tensile Strength: 165.79 kPa
# MAvg - Exp10 - JJA
# Best Threshold=0.361730
# F-Score=0.854
# Tensile Strength: 57.734 kPa
# MAvg - Exp11 - Decadal
# Best Threshold=0.346711
# F-Score=0.844
# Tensile Strength: 104.869 kPa
# MAvg - Exp11 - Annual
# Best Threshold=0.342874
# F-Score=0.845
# Tensile Strength: 106.971 kPa
# MAvg - Exp11 - DJF
# Best Threshold=0.348616
# F-Score=0.848
# Tensile Strength: 160.052 kPa
# MAvg - Exp11 - JJA
# Best Threshold=0.356325
# F-Score=0.846
# Tensile Strength: 56.251 kPa
# MAvg - Exp12 - Decadal
# Best Threshold=0.336251
# F-Score=0.830
# Tensile Strength: 101.772 kPa
# MAvg - Exp12 - Annual
# Best Threshold=0.348641
# F-Score=0.831
# Tensile Strength: 105.358 kPa
# MAvg - Exp12 - DJF
# Best Threshold=0.346604
# F-Score=0.835
# Tensile Strength: 156.882 kPa
# MAvg - Exp12 - JJA
# Best Threshold=0.346495
# F-Score=0.831
# Tensile Strength: 54.792 kPa
# MAvg - Exp13 - Decadal
# Best Threshold=0.389627
# F-Score=0.818
# Tensile Strength: 105.04 kPa
# MAvg - Exp13 - Annual
# Best Threshold=0.388444
# F-Score=0.819
# Tensile Strength: 107.457 kPa
# MAvg - Exp13 - DJF
# Best Threshold=0.395029
# F-Score=0.821
# Tensile Strength: 160.965 kPa
# MAvg - Exp13 - JJA
# Best Threshold=0.372323
# F-Score=0.816
# Tensile Strength: 55.02 kPa
# MAvg - Exp14 - Decadal
# Best Threshold=0.392017
# F-Score=0.807
# Tensile Strength: 103.873 kPa
# MAvg - Exp14 - Annual
# Best Threshold=0.381376
# F-Score=0.807
# Tensile Strength: 105.395 kPa
# MAvg - Exp14 - DJF
# Best Threshold=0.391515
# F-Score=0.812
# Tensile Strength: 158.446 kPa
# MAvg - Exp14 - JJA
# Best Threshold=0.382734
# F-Score=0.806
# Tensile Strength: 54.817 kPa
# MAvg - Exp15 - Decadal
# Best Threshold=0.396768
# F-Score=0.800
# Tensile Strength: 124.507 kPa
# MAvg - Exp15 - Annual
# Best Threshold=0.392110
# F-Score=0.802
# Tensile Strength: 126.994 kPa
# MAvg - Exp15 - DJF
# Best Threshold=0.377475
# F-Score=0.802
# Tensile Strength: 187.105 kPa
# MAvg - Exp15 - JJA
# Best Threshold=0.385274
# F-Score=0.797
# Tensile Strength: 65.729 kPa
# MAvg - Exp16 - Decadal
# Best Threshold=0.392187
# F-Score=0.839
# Tensile Strength: 117.169 kPa
# MAvg - Exp16 - Annual
# Best Threshold=0.381890
# F-Score=0.836
# Tensile Strength: 119.1 kPa
# MAvg - Exp16 - DJF
# Best Threshold=0.396484
# F-Score=0.839
# Tensile Strength: 179.143 kPa
# MAvg - Exp16 - JJA
# Best Threshold=0.390727
# F-Score=0.837
# Tensile Strength: 62.338 kPa
# MAvg - Exp17 - Decadal
# Best Threshold=0.369096
# F-Score=0.854
# Tensile Strength: 111.325 kPa
# MAvg - Exp17 - Annual
# Best Threshold=0.371165
# F-Score=0.854
# Tensile Strength: 114.153 kPa
# MAvg - Exp17 - DJF
# Best Threshold=0.364488
# F-Score=0.855
# Tensile Strength: 169.373 kPa
# MAvg - Exp17 - JJA
# Best Threshold=0.385924
# F-Score=0.851
# Tensile Strength: 59.936 kPa
# MAvg - Exp18 - Decadal
# Best Threshold=0.377795
# F-Score=0.858
# Tensile Strength: 109.508 kPa
# MAvg - Exp18 - Annual
# Best Threshold=0.354647
# F-Score=0.859
# Tensile Strength: 110.074 kPa
# MAvg - Exp18 - DJF
# Best Threshold=0.360412
# F-Score=0.859
# Tensile Strength: 164.785 kPa
# MAvg - Exp18 - JJA
# Best Threshold=0.363032
# F-Score=0.857
# Tensile Strength: 57.636 kPa
# MAvg - Exp19 - Decadal
# Best Threshold=0.366484
# F-Score=0.849
# Tensile Strength: 106.621 kPa
# MAvg - Exp19 - Annual
# Best Threshold=0.362122
# F-Score=0.852
# Tensile Strength: 108.802 kPa
# MAvg - Exp19 - DJF
# Best Threshold=0.336402
# F-Score=0.851
# Tensile Strength: 158.956 kPa
# MAvg - Exp19 - JJA
# Best Threshold=0.361809
# F-Score=0.850
# Tensile Strength: 56.571 kPa
# MAvg - Exp20 - Decadal
# Best Threshold=0.331861
# F-Score=0.838
# Tensile Strength: 101.833 kPa
# MAvg - Exp20 - Annual
# Best Threshold=0.331225
# F-Score=0.839
# Tensile Strength: 104.222 kPa
# MAvg - Exp20 - DJF
# Best Threshold=0.330775
# F-Score=0.841
# Tensile Strength: 155.587 kPa
# MAvg - Exp20 - JJA
# Best Threshold=0.330695
# F-Score=0.838
# Tensile Strength: 54.253 kPa
# MAvg - Exp21 - Decadal
# Best Threshold=0.372565
# F-Score=0.824
# Tensile Strength: 104.094 kPa
# MAvg - Exp21 - Annual
# Best Threshold=0.371135
# F-Score=0.830
# Tensile Strength: 106.415 kPa
# MAvg - Exp21 - DJF
# Best Threshold=0.354897
# F-Score=0.829
# Tensile Strength: 156.474 kPa
# MAvg - Exp21 - JJA
# Best Threshold=0.354358
# F-Score=0.827
# Tensile Strength: 54.552 kPa
# MAvg - Exp22 - Decadal
# Best Threshold=0.374996
# F-Score=0.808
# Tensile Strength: 120.507 kPa
# MAvg - Exp22 - Annual
# Best Threshold=0.374228
# F-Score=0.809
# Tensile Strength: 123.098 kPa
# MAvg - Exp22 - DJF
# Best Threshold=0.376240
# F-Score=0.811
# Tensile Strength: 183.662 kPa
# MAvg - Exp22 - JJA
# Best Threshold=0.394682
# F-Score=0.807
# Tensile Strength: 65.01 kPa
# MAvg - Exp23 - Decadal
# Best Threshold=0.400950
# F-Score=0.837
# Tensile Strength: 114.677 kPa
# MAvg - Exp23 - Annual
# Best Threshold=0.387974
# F-Score=0.840
# Tensile Strength: 116.239 kPa
# MAvg - Exp23 - DJF
# Best Threshold=0.362941
# F-Score=0.840
# Tensile Strength: 170.264 kPa
# MAvg - Exp23 - JJA
# Best Threshold=0.377041
# F-Score=0.837
# Tensile Strength: 60.006 kPa
# MAvg - Exp24 - Decadal
# Best Threshold=0.380199
# F-Score=0.832
# Tensile Strength: 109.096 kPa
# MAvg - Exp24 - Annual
# Best Threshold=0.393886
# F-Score=0.834
# Tensile Strength: 112.774 kPa
# MAvg - Exp24 - DJF
# Best Threshold=0.360998
# F-Score=0.836
# Tensile Strength: 163.85 kPa
# MAvg - Exp24 - JJA
# Best Threshold=0.402602
# F-Score=0.835
# Tensile Strength: 59.062 kPa
# MAvg - Exp25 - Decadal
# Best Threshold=0.375004
# F-Score=0.815
# Tensile Strength: 105.96 kPa
# MAvg - Exp25 - Annual
# Best Threshold=0.369999
# F-Score=0.815
# Tensile Strength: 107.985 kPa
# MAvg - Exp25 - DJF
# Best Threshold=0.373018
# F-Score=0.819
# Tensile Strength: 161.24 kPa
# MAvg - Exp25 - JJA
# Best Threshold=0.393169
# F-Score=0.813
# Tensile Strength: 57.297 kPa
# MAvg - Exp26 - Decadal
# Best Threshold=0.393973
# F-Score=0.795
# Tensile Strength: 105.818 kPa
# MAvg - Exp26 - Annual
# Best Threshold=0.409335
# F-Score=0.800
# Tensile Strength: 109.812 kPa
# MAvg - Exp26 - DJF
# Best Threshold=0.404546
# F-Score=0.802
# Tensile Strength: 162.978 kPa
# MAvg - Exp26 - JJA
# Best Threshold=0.404449
# F-Score=0.798
# Tensile Strength: 56.781 kPa
# MAvg - Exp27 - Decadal
# Best Threshold=0.412753
# F-Score=0.780
# Tensile Strength: 106.142 kPa
# MAvg - Exp27 - Annual
# Best Threshold=0.427542
# F-Score=0.784
# Tensile Strength: 110.064 kPa
# MAvg - Exp27 - DJF
# Best Threshold=0.403059
# F-Score=0.781
# Tensile Strength: 160.376 kPa
# MAvg - Exp27 - JJA
# Best Threshold=0.427288
# F-Score=0.780
# Tensile Strength: 57.148 kPa
# MAvg - Exp28 - Decadal
# Best Threshold=0.403674
# F-Score=0.766
# Tensile Strength: 103.771 kPa
# MAvg - Exp28 - Annual
# Best Threshold=0.400945
# F-Score=0.766
# Tensile Strength: 105.774 kPa
# MAvg - Exp28 - DJF
# Best Threshold=0.408320
# F-Score=0.767
# Tensile Strength: 159.052 kPa
# MAvg - Exp28 - JJA
# Best Threshold=0.385424
# F-Score=0.761
# Tensile Strength: 54.111 kPa
# M12 - Exp1 - Decadal
# Best Threshold=0.382725
# F-Score=0.792
# Tensile Strength: 129.098 kPa
# M12 - Exp1 - Annual
# Best Threshold=0.353318
# F-Score=0.794
# Tensile Strength: 129.095 kPa
# M12 - Exp1 - DJF
# Best Threshold=0.352683
# F-Score=0.798
# Tensile Strength: 192.54 kPa
# M12 - Exp1 - JJA
# Best Threshold=0.387694
# F-Score=0.793
# Tensile Strength: 68.871 kPa
# M12 - Exp2 - Decadal
# Best Threshold=0.341787
# F-Score=0.832
# Tensile Strength: 116.141 kPa
# M12 - Exp2 - Annual
# Best Threshold=0.346287
# F-Score=0.831
# Tensile Strength: 119.154 kPa
# M12 - Exp2 - DJF
# Best Threshold=0.339310
# F-Score=0.835
# Tensile Strength: 176.636 kPa
# M12 - Exp2 - JJA
# Best Threshold=0.331001
# F-Score=0.833
# Tensile Strength: 61.211 kPa
# M12 - Exp3 - Decadal
# Best Threshold=0.349063
# F-Score=0.841
# Tensile Strength: 111.3 kPa
# M12 - Exp3 - Annual
# Best Threshold=0.330683
# F-Score=0.841
# Tensile Strength: 112.11 kPa
# M12 - Exp3 - DJF
# Best Threshold=0.325464
# F-Score=0.842
# Tensile Strength: 166.846 kPa
# M12 - Exp3 - JJA
# Best Threshold=0.338788
# F-Score=0.839
# Tensile Strength: 58.774 kPa
# M12 - Exp4 - Decadal
# Best Threshold=0.355483
# F-Score=0.829
# Tensile Strength: 108.569 kPa
# M12 - Exp4 - Annual
# Best Threshold=0.347704
# F-Score=0.828
# Tensile Strength: 110.448 kPa
# M12 - Exp4 - DJF
# Best Threshold=0.352393
# F-Score=0.833
# Tensile Strength: 165.643 kPa
# M12 - Exp4 - JJA
# Best Threshold=0.363320
# F-Score=0.825
# Tensile Strength: 58.191 kPa
# M12 - Exp5 - Decadal
# Best Threshold=0.388594
# F-Score=0.818
# Tensile Strength: 109.489 kPa
# M12 - Exp5 - Annual
# Best Threshold=0.374969
# F-Score=0.821
# Tensile Strength: 110.624 kPa
# M12 - Exp5 - DJF
# Best Threshold=0.377316
# F-Score=0.829
# Tensile Strength: 165.345 kPa
# M12 - Exp5 - JJA
# Best Threshold=0.399231
# F-Score=0.826
# Tensile Strength: 58.676 kPa
# M12 - Exp6 - Decadal
# Best Threshold=0.391385
# F-Score=0.814
# Tensile Strength: 107.504 kPa
# M12 - Exp6 - Annual
# Best Threshold=0.378713
# F-Score=0.811
# Tensile Strength: 108.795 kPa
# M12 - Exp6 - DJF
# Best Threshold=0.321710
# F-Score=0.812
# Tensile Strength: 153.295 kPa
# M12 - Exp6 - JJA
# Best Threshold=0.364579
# F-Score=0.818
# Tensile Strength: 55.592 kPa
# M12 - Exp7 - Decadal
# Best Threshold=0.417523
# F-Score=0.811
# Tensile Strength: 108.964 kPa
# M12 - Exp7 - Annual
# Best Threshold=0.389739
# F-Score=0.808
# Tensile Strength: 108.4 kPa
# M12 - Exp7 - DJF
# Best Threshold=0.348073
# F-Score=0.805
# Tensile Strength: 154.441 kPa
# M12 - Exp7 - JJA
# Best Threshold=0.395088
# F-Score=0.807
# Tensile Strength: 56.392 kPa
# M12 - Exp8 - Decadal
# Best Threshold=0.374262
# F-Score=0.787
# Tensile Strength: 129.44 kPa
# M12 - Exp8 - Annual
# Best Threshold=0.359986
# F-Score=0.785
# Tensile Strength: 131.044 kPa
# M12 - Exp8 - DJF
# Best Threshold=0.391134
# F-Score=0.787
# Tensile Strength: 200.771 kPa
# M12 - Exp8 - JJA
# Best Threshold=0.387333
# F-Score=0.782
# Tensile Strength: 69.608 kPa
# M12 - Exp9 - Decadal
# Best Threshold=0.327331
# F-Score=0.829
# Tensile Strength: 116.126 kPa
# M12 - Exp9 - Annual
# Best Threshold=0.344673
# F-Score=0.831
# Tensile Strength: 120.2 kPa
# M12 - Exp9 - DJF
# Best Threshold=0.331039
# F-Score=0.830
# Tensile Strength: 177.76 kPa
# M12 - Exp9 - JJA
# Best Threshold=0.335888
# F-Score=0.825
# Tensile Strength: 62.294 kPa
# M12 - Exp10 - Decadal
# Best Threshold=0.352458
# F-Score=0.841
# Tensile Strength: 112.592 kPa
# M12 - Exp10 - Annual
# Best Threshold=0.349944
# F-Score=0.846
# Tensile Strength: 115.043 kPa
# M12 - Exp10 - DJF
# Best Threshold=0.327939
# F-Score=0.844
# Tensile Strength: 168.346 kPa
# M12 - Exp10 - JJA
# Best Threshold=0.320378
# F-Score=0.842
# Tensile Strength: 58.322 kPa
# M12 - Exp11 - Decadal
# Best Threshold=0.355086
# F-Score=0.836
# Tensile Strength: 109.77 kPa
# M12 - Exp11 - Annual
# Best Threshold=0.346924
# F-Score=0.836
# Tensile Strength: 111.264 kPa
# M12 - Exp11 - DJF
# Best Threshold=0.322174
# F-Score=0.845
# Tensile Strength: 162.521 kPa
# M12 - Exp11 - JJA
# Best Threshold=0.361065
# F-Score=0.842
# Tensile Strength: 58.459 kPa
# M12 - Exp12 - Decadal
# Best Threshold=0.322878
# F-Score=0.824
# Tensile Strength: 103.517 kPa
# M12 - Exp12 - Annual
# Best Threshold=0.353014
# F-Score=0.834
# Tensile Strength: 109.297 kPa
# M12 - Exp12 - DJF
# Best Threshold=0.361491
# F-Score=0.834
# Tensile Strength: 164.239 kPa
# M12 - Exp12 - JJA
# Best Threshold=0.363411
# F-Score=0.836
# Tensile Strength: 57.355 kPa
# M12 - Exp13 - Decadal
# Best Threshold=0.335910
# F-Score=0.818
# Tensile Strength: 102.783 kPa
# M12 - Exp13 - Annual
# Best Threshold=0.356726
# F-Score=0.822
# Tensile Strength: 107.889 kPa
# M12 - Exp13 - DJF
# Best Threshold=0.343906
# F-Score=0.827
# Tensile Strength: 158.314 kPa
# M12 - Exp13 - JJA
# Best Threshold=0.373099
# F-Score=0.822
# Tensile Strength: 56.667 kPa
# M12 - Exp14 - Decadal
# Best Threshold=0.388741
# F-Score=0.819
# Tensile Strength: 106.761 kPa
# M12 - Exp14 - Annual
# Best Threshold=0.356360
# F-Score=0.814
# Tensile Strength: 105.954 kPa
# M12 - Exp14 - DJF
# Best Threshold=0.332628
# F-Score=0.816
# Tensile Strength: 153.692 kPa
# M12 - Exp14 - JJA
# Best Threshold=0.355378
# F-Score=0.816
# Tensile Strength: 54.839 kPa
# M12 - Exp15 - Decadal
# Best Threshold=0.359783
# F-Score=0.803
# Tensile Strength: 125.179 kPa
# M12 - Exp15 - Annual
# Best Threshold=0.355120
# F-Score=0.804
# Tensile Strength: 127.637 kPa
# M12 - Exp15 - DJF
# Best Threshold=0.377617
# F-Score=0.808
# Tensile Strength: 193.11 kPa
# M12 - Exp15 - JJA
# Best Threshold=0.355324
# F-Score=0.795
# Tensile Strength: 66.411 kPa
# M12 - Exp16 - Decadal
# Best Threshold=0.357964
# F-Score=0.803
# Tensile Strength: 125.179 kPa
# M12 - Exp16 - Annual
# Best Threshold=0.353222
# F-Score=0.804
# Tensile Strength: 127.637 kPa
# M12 - Exp16 - DJF
# Best Threshold=0.365855
# F-Score=0.810
# Tensile Strength: 191.525 kPa
# M12 - Exp16 - JJA
# Best Threshold=0.353393
# F-Score=0.800
# Tensile Strength: 66.152 kPa
# M12 - Exp17 - Decadal
# Best Threshold=0.345144
# F-Score=0.848
# Tensile Strength: 112.142 kPa
# M12 - Exp17 - Annual
# Best Threshold=0.343553
# F-Score=0.850
# Tensile Strength: 114.754 kPa
# M12 - Exp17 - DJF
# Best Threshold=0.350909
# F-Score=0.850
# Tensile Strength: 172.007 kPa
# M12 - Exp17 - JJA
# Best Threshold=0.338639
# F-Score=0.844
# Tensile Strength: 59.291 kPa
# M12 - Exp18 - Decadal
# Best Threshold=0.343348
# F-Score=0.844
# Tensile Strength: 112.075 kPa
# M12 - Exp18 - Annual
# Best Threshold=0.342764
# F-Score=0.846
# Tensile Strength: 114.778 kPa
# M12 - Exp18 - DJF
# Best Threshold=0.345675
# F-Score=0.848
# Tensile Strength: 171.546 kPa
# M12 - Exp18 - JJA
# Best Threshold=0.335583
# F-Score=0.845
# Tensile Strength: 59.304 kPa
# M12 - Exp19 - Decadal
# Best Threshold=0.334537
# F-Score=0.841
# Tensile Strength: 106.211 kPa
# M12 - Exp19 - Annual
# Best Threshold=0.319285
# F-Score=0.839
# Tensile Strength: 106.844 kPa
# M12 - Exp19 - DJF
# Best Threshold=0.336617
# F-Score=0.844
# Tensile Strength: 162.295 kPa
# M12 - Exp19 - JJA
# Best Threshold=0.353042
# F-Score=0.843
# Tensile Strength: 57.39 kPa
# M12 - Exp20 - Decadal
# Best Threshold=0.301134
# F-Score=0.833
# Tensile Strength: 102.417 kPa
# M12 - Exp20 - Annual
# Best Threshold=0.334869
# F-Score=0.841
# Tensile Strength: 108.382 kPa
# M12 - Exp20 - DJF
# Best Threshold=0.336412
# F-Score=0.844
# Tensile Strength: 162.295 kPa
# M12 - Exp20 - JJA
# Best Threshold=0.353285
# F-Score=0.845
# Tensile Strength: 57.375 kPa
# M12 - Exp21 - Decadal
# Best Threshold=0.374982
# F-Score=0.827
# Tensile Strength: 106.939 kPa
# M12 - Exp21 - Annual
# Best Threshold=0.382967
# F-Score=0.830
# Tensile Strength: 110.29 kPa
# M12 - Exp21 - DJF
# Best Threshold=0.346014
# F-Score=0.830
# Tensile Strength: 158.672 kPa
# M12 - Exp21 - JJA
# Best Threshold=0.394996
# F-Score=0.831
# Tensile Strength: 57.798 kPa
# M12 - Exp22 - Decadal
# Best Threshold=0.407642
# F-Score=0.742
# Tensile Strength: 140.554 kPa
# M12 - Exp22 - Annual
# Best Threshold=0.369374
# F-Score=0.740
# Tensile Strength: 139.004 kPa
# M12 - Exp22 - DJF
# Best Threshold=0.366494
# F-Score=0.743
# Tensile Strength: 205.806 kPa
# M12 - Exp22 - JJA
# Best Threshold=0.386402
# F-Score=0.740
# Tensile Strength: 73.243 kPa
# M12 - Exp23 - Decadal
# Best Threshold=0.380844
# F-Score=0.804
# Tensile Strength: 124.775 kPa
# M12 - Exp23 - Annual
# Best Threshold=0.382589
# F-Score=0.809
# Tensile Strength: 127.671 kPa
# M12 - Exp23 - DJF
# Best Threshold=0.383557
# F-Score=0.806
# Tensile Strength: 190.151 kPa
# M12 - Exp23 - JJA
# Best Threshold=0.377019
# F-Score=0.806
# Tensile Strength: 66.195 kPa
# M12 - Exp24 - Decadal
# Best Threshold=0.361105
# F-Score=0.820
# Tensile Strength: 115.333 kPa
# M12 - Exp24 - Annual
# Best Threshold=0.360581
# F-Score=0.818
# Tensile Strength: 117.701 kPa
# M12 - Exp24 - DJF
# Best Threshold=0.361430
# F-Score=0.826
# Tensile Strength: 175.493 kPa
# M12 - Exp24 - JJA
# Best Threshold=0.370380
# F-Score=0.819
# Tensile Strength: 61.661 kPa
# M12 - Exp25 - Decadal
# Best Threshold=0.359333
# F-Score=0.811
# Tensile Strength: 110.888 kPa
# M12 - Exp25 - Annual
# Best Threshold=0.362665
# F-Score=0.806
# Tensile Strength: 113.763 kPa
# M12 - Exp25 - DJF
# Best Threshold=0.344706
# F-Score=0.805
# Tensile Strength: 166.539 kPa
# M12 - Exp25 - JJA
# Best Threshold=0.350693
# F-Score=0.801
# Tensile Strength: 58.422 kPa
# M12 - Exp26 - Decadal
# Best Threshold=0.377982
# F-Score=0.789
# Tensile Strength: 109.741 kPa
# M12 - Exp26 - Annual
# Best Threshold=0.387162
# F-Score=0.796
# Tensile Strength: 113.189 kPa
# M12 - Exp26 - DJF
# Best Threshold=0.363326
# F-Score=0.791
# Tensile Strength: 164.842 kPa
# M12 - Exp26 - JJA
# Best Threshold=0.383306
# F-Score=0.793
# Tensile Strength: 58.577 kPa
# M12 - Exp27 - Decadal
# Best Threshold=0.391951
# F-Score=0.772
# Tensile Strength: 108.723 kPa
# M12 - Exp27 - Annual
# Best Threshold=0.382537
# F-Score=0.779
# Tensile Strength: 110.306 kPa
# M12 - Exp27 - DJF
# Best Threshold=0.373869
# F-Score=0.786
# Tensile Strength: 162.647 kPa
# M12 - Exp27 - JJA
# Best Threshold=0.409141
# F-Score=0.780
# Tensile Strength: 58.678 kPa
# M12 - Exp28 - Decadal
# Best Threshold=0.380776
# F-Score=0.764
# Tensile Strength: 105.339 kPa
# M12 - Exp28 - Annual
# Best Threshold=0.365198
# F-Score=0.766
# Tensile Strength: 105.777 kPa
# M12 - Exp28 - DJF
# Best Threshold=0.367811
# F-Score=0.771
# Tensile Strength: 158.391 kPa
# M12 - Exp28 - JJA
# Best Threshold=0.393426
# F-Score=0.761
# Tensile Strength: 56.777 kPa
# ILAvg - Exp1 - Decadal
# Best Threshold=0.378216
# F-Score=0.773
# Tensile Strength: 120.96 kPa
# ILAvg - Exp1 - Annual
# Best Threshold=0.375935
# F-Score=0.772
# Tensile Strength: 123.428 kPa
# ILAvg - Exp1 - DJF
# Best Threshold=0.384262
# F-Score=0.772
# Tensile Strength: 185.279 kPa
# ILAvg - Exp1 - JJA
# Best Threshold=0.389929
# F-Score=0.768
# Tensile Strength: 65.025 kPa
# ILAvg - Exp2 - Decadal
# Best Threshold=0.384946
# F-Score=0.789
# Tensile Strength: 118.942 kPa
# ILAvg - Exp2 - Annual
# Best Threshold=0.384318
# F-Score=0.789
# Tensile Strength: 121.43 kPa
# ILAvg - Exp2 - DJF
# Best Threshold=0.393440
# F-Score=0.790
# Tensile Strength: 182.195 kPa
# ILAvg - Exp2 - JJA
# Best Threshold=0.369095
# F-Score=0.784
# Tensile Strength: 62.435 kPa
# ILAvg - Exp3 - Decadal
# Best Threshold=0.391094
# F-Score=0.794
# Tensile Strength: 115.971 kPa
# ILAvg - Exp3 - Annual
# Best Threshold=0.386105
# F-Score=0.796
# Tensile Strength: 118.028 kPa
# ILAvg - Exp3 - DJF
# Best Threshold=0.391118
# F-Score=0.795
# Tensile Strength: 176.619 kPa
# ILAvg - Exp3 - JJA
# Best Threshold=0.395661
# F-Score=0.795
# Tensile Strength: 61.835 kPa
# ILAvg - Exp4 - Decadal
# Best Threshold=0.391563
# F-Score=0.790
# Tensile Strength: 113.951 kPa
# ILAvg - Exp4 - Annual
# Best Threshold=0.384990
# F-Score=0.791
# Tensile Strength: 115.873 kPa
# ILAvg - Exp4 - DJF
# Best Threshold=0.400048
# F-Score=0.790
# Tensile Strength: 174.89 kPa
# ILAvg - Exp4 - JJA
# Best Threshold=0.393998
# F-Score=0.788
# Tensile Strength: 60.733 kPa
# ILAvg - Exp5 - Decadal
# Best Threshold=0.400533
# F-Score=0.786
# Tensile Strength: 113.071 kPa
# ILAvg - Exp5 - Annual
# Best Threshold=0.393303
# F-Score=0.787
# Tensile Strength: 114.891 kPa
# ILAvg - Exp5 - DJF
# Best Threshold=0.410059
# F-Score=0.788
# Tensile Strength: 173.749 kPa
# ILAvg - Exp5 - JJA
# Best Threshold=0.388313
# F-Score=0.783
# Tensile Strength: 59.516 kPa
# ILAvg - Exp6 - Decadal
# Best Threshold=0.414565
# F-Score=0.781
# Tensile Strength: 113.294 kPa
# ILAvg - Exp6 - Annual
# Best Threshold=0.422336
# F-Score=0.782
# Tensile Strength: 116.664 kPa
# ILAvg - Exp6 - DJF
# Best Threshold=0.428370
# F-Score=0.785
# Tensile Strength: 174.678 kPa
# ILAvg - Exp6 - JJA
# Best Threshold=0.409956
# F-Score=0.779
# Tensile Strength: 59.911 kPa
# ILAvg - Exp7 - Decadal
# Best Threshold=0.413513
# F-Score=0.777
# Tensile Strength: 111.96 kPa
# ILAvg - Exp7 - Annual
# Best Threshold=0.407200
# F-Score=0.773
# Tensile Strength: 114.156 kPa
# ILAvg - Exp7 - DJF
# Best Threshold=0.411543
# F-Score=0.775
# Tensile Strength: 170.554 kPa
# ILAvg - Exp7 - JJA
# Best Threshold=0.442350
# F-Score=0.775
# Tensile Strength: 61.088 kPa
# ILAvg - Exp8 - Decadal
# Best Threshold=0.376904
# F-Score=0.771
# Tensile Strength: 121.086 kPa
# ILAvg - Exp8 - Annual
# Best Threshold=0.387383
# F-Score=0.769
# Tensile Strength: 125.08 kPa
# ILAvg - Exp8 - DJF
# Best Threshold=0.380520
# F-Score=0.769
# Tensile Strength: 184.89 kPa
# ILAvg - Exp8 - JJA
# Best Threshold=0.391802
# F-Score=0.766
# Tensile Strength: 65.24 kPa
# ILAvg - Exp9 - Decadal
# Best Threshold=0.377243
# F-Score=0.789
# Tensile Strength: 118.688 kPa
# ILAvg - Exp9 - Annual
# Best Threshold=0.375559
# F-Score=0.786
# Tensile Strength: 121.149 kPa
# ILAvg - Exp9 - DJF
# Best Threshold=0.391984
# F-Score=0.788
# Tensile Strength: 182.765 kPa
# ILAvg - Exp9 - JJA
# Best Threshold=0.397780
# F-Score=0.784
# Tensile Strength: 64.143 kPa
# ILAvg - Exp10 - Decadal
# Best Threshold=0.387794
# F-Score=0.795
# Tensile Strength: 116.2 kPa
# ILAvg - Exp10 - Annual
# Best Threshold=0.368533
# F-Score=0.793
# Tensile Strength: 116.947 kPa
# ILAvg - Exp10 - DJF
# Best Threshold=0.388578
# F-Score=0.796
# Tensile Strength: 177.231 kPa
# ILAvg - Exp10 - JJA
# Best Threshold=0.390873
# F-Score=0.794
# Tensile Strength: 62.0 kPa
# ILAvg - Exp11 - Decadal
# Best Threshold=0.388443
# F-Score=0.794
# Tensile Strength: 114.26 kPa
# ILAvg - Exp11 - Annual
# Best Threshold=0.390013
# F-Score=0.795
# Tensile Strength: 117.149 kPa
# ILAvg - Exp11 - DJF
# Best Threshold=0.401016
# F-Score=0.796
# Tensile Strength: 176.038 kPa
# ILAvg - Exp11 - JJA
# Best Threshold=0.384400
# F-Score=0.791
# Tensile Strength: 60.61 kPa
# ILAvg - Exp12 - Decadal
# Best Threshold=0.402682
# F-Score=0.791
# Tensile Strength: 114.001 kPa
# ILAvg - Exp12 - Annual
# Best Threshold=0.397972
# F-Score=0.793
# Tensile Strength: 116.101 kPa
# ILAvg - Exp12 - DJF
# Best Threshold=0.391809
# F-Score=0.791
# Tensile Strength: 172.218 kPa
# ILAvg - Exp12 - JJA
# Best Threshold=0.392110
# F-Score=0.789
# Tensile Strength: 60.106 kPa
# ILAvg - Exp13 - Decadal
# Best Threshold=0.396184
# F-Score=0.786
# Tensile Strength: 111.901 kPa
# ILAvg - Exp13 - Annual
# Best Threshold=0.381505
# F-Score=0.786
# Tensile Strength: 113.17 kPa
# ILAvg - Exp13 - DJF
# Best Threshold=0.412052
# F-Score=0.787
# Tensile Strength: 173.211 kPa
# ILAvg - Exp13 - JJA
# Best Threshold=0.390297
# F-Score=0.781
# Tensile Strength: 59.305 kPa
# ILAvg - Exp14 - Decadal
# Best Threshold=0.413097
# F-Score=0.785
# Tensile Strength: 112.632 kPa
# ILAvg - Exp14 - Annual
# Best Threshold=0.382786
# F-Score=0.779
# Tensile Strength: 112.146 kPa
# ILAvg - Exp14 - DJF
# Best Threshold=0.414909
# F-Score=0.785
# Tensile Strength: 171.951 kPa
# ILAvg - Exp14 - JJA
# Best Threshold=0.413066
# F-Score=0.781
# Tensile Strength: 59.901 kPa
# ILAvg - Exp15 - Decadal
# Best Threshold=0.374245
# F-Score=0.761
# Tensile Strength: 121.34 kPa
# ILAvg - Exp15 - Annual
# Best Threshold=0.378913
# F-Score=0.764
# Tensile Strength: 124.454 kPa
# ILAvg - Exp15 - DJF
# Best Threshold=0.381095
# F-Score=0.763
# Tensile Strength: 185.951 kPa
# ILAvg - Exp15 - JJA
# Best Threshold=0.387840
# F-Score=0.758
# Tensile Strength: 65.369 kPa
# ILAvg - Exp16 - Decadal
# Best Threshold=0.378207
# F-Score=0.779
# Tensile Strength: 120.018 kPa
# ILAvg - Exp16 - Annual
# Best Threshold=0.382648
# F-Score=0.783
# Tensile Strength: 123.034 kPa
# ILAvg - Exp16 - DJF
# Best Threshold=0.387677
# F-Score=0.781
# Tensile Strength: 184.196 kPa
# ILAvg - Exp16 - JJA
# Best Threshold=0.402234
# F-Score=0.775
# Tensile Strength: 65.177 kPa
# ILAvg - Exp17 - Decadal
# Best Threshold=0.390320
# F-Score=0.788
# Tensile Strength: 119.105 kPa
# ILAvg - Exp17 - Annual
# Best Threshold=0.387188
# F-Score=0.789
# Tensile Strength: 121.627 kPa
# ILAvg - Exp17 - DJF
# Best Threshold=0.391646
# F-Score=0.789
# Tensile Strength: 181.759 kPa
# ILAvg - Exp17 - JJA
# Best Threshold=0.392127
# F-Score=0.787
# Tensile Strength: 63.487 kPa
# ILAvg - Exp18 - Decadal
# Best Threshold=0.388891
# F-Score=0.793
# Tensile Strength: 117.135 kPa
# ILAvg - Exp18 - Annual
# Best Threshold=0.365076
# F-Score=0.793
# Tensile Strength: 117.477 kPa
# ILAvg - Exp18 - DJF
# Best Threshold=0.378231
# F-Score=0.793
# Tensile Strength: 176.908 kPa
# ILAvg - Exp18 - JJA
# Best Threshold=0.391782
# F-Score=0.790
# Tensile Strength: 62.442 kPa
# ILAvg - Exp19 - Decadal
# Best Threshold=0.383916
# F-Score=0.795
# Tensile Strength: 114.898 kPa
# ILAvg - Exp19 - Annual
# Best Threshold=0.367084
# F-Score=0.793
# Tensile Strength: 115.961 kPa
# ILAvg - Exp19 - DJF
# Best Threshold=0.367208
# F-Score=0.794
# Tensile Strength: 172.821 kPa
# ILAvg - Exp19 - JJA
# Best Threshold=0.392465
# F-Score=0.794
# Tensile Strength: 61.575 kPa
# ILAvg - Exp20 - Decadal
# Best Threshold=0.399671
# F-Score=0.796
# Tensile Strength: 114.871 kPa
# ILAvg - Exp20 - Annual
# Best Threshold=0.384533
# F-Score=0.798
# Tensile Strength: 115.909 kPa
# ILAvg - Exp20 - DJF
# Best Threshold=0.411924
# F-Score=0.799
# Tensile Strength: 176.869 kPa
# ILAvg - Exp20 - JJA
# Best Threshold=0.390997
# F-Score=0.794
# Tensile Strength: 60.666 kPa
# ILAvg - Exp21 - Decadal
# Best Threshold=0.393414
# F-Score=0.792
# Tensile Strength: 113.038 kPa
# ILAvg - Exp21 - Annual
# Best Threshold=0.390060
# F-Score=0.795
# Tensile Strength: 115.211 kPa
# ILAvg - Exp21 - DJF
# Best Threshold=0.395487
# F-Score=0.796
# Tensile Strength: 172.63 kPa
# ILAvg - Exp21 - JJA
# Best Threshold=0.395829
# F-Score=0.788
# Tensile Strength: 60.211 kPa
# ILAvg - Exp22 - Decadal
# Best Threshold=0.377413
# F-Score=0.767
# Tensile Strength: 121.175 kPa
# ILAvg - Exp22 - Annual
# Best Threshold=0.390848
# F-Score=0.768
# Tensile Strength: 125.443 kPa
# ILAvg - Exp22 - DJF
# Best Threshold=0.396080
# F-Score=0.770
# Tensile Strength: 187.772 kPa
# ILAvg - Exp22 - JJA
# Best Threshold=0.391812
# F-Score=0.761
# Tensile Strength: 65.276 kPa
# ILAvg - Exp23 - Decadal
# Best Threshold=0.375297
# F-Score=0.782
# Tensile Strength: 117.089 kPa
# ILAvg - Exp23 - Annual
# Best Threshold=0.369354
# F-Score=0.782
# Tensile Strength: 119.133 kPa
# ILAvg - Exp23 - DJF
# Best Threshold=0.377466
# F-Score=0.782
# Tensile Strength: 178.828 kPa
# ILAvg - Exp23 - JJA
# Best Threshold=0.374704
# F-Score=0.777
# Tensile Strength: 62.343 kPa
# ILAvg - Exp24 - Decadal
# Best Threshold=0.386707
# F-Score=0.783
# Tensile Strength: 115.44 kPa
# ILAvg - Exp24 - Annual
# Best Threshold=0.377373
# F-Score=0.785
# Tensile Strength: 117.097 kPa
# ILAvg - Exp24 - DJF
# Best Threshold=0.383875
# F-Score=0.786
# Tensile Strength: 175.615 kPa
# ILAvg - Exp24 - JJA
# Best Threshold=0.392566
# F-Score=0.781
# Tensile Strength: 61.764 kPa
# ILAvg - Exp25 - Decadal
# Best Threshold=0.385125
# F-Score=0.774
# Tensile Strength: 113.342 kPa
# ILAvg - Exp25 - Annual
# Best Threshold=0.382349
# F-Score=0.775
# Tensile Strength: 115.487 kPa
# ILAvg - Exp25 - DJF
# Best Threshold=0.386903
# F-Score=0.776
# Tensile Strength: 173.051 kPa
# ILAvg - Exp25 - JJA
# Best Threshold=0.403420
# F-Score=0.775
# Tensile Strength: 61.256 kPa
# ILAvg - Exp26 - Decadal
# Best Threshold=0.397369
# F-Score=0.767
# Tensile Strength: 112.999 kPa
# ILAvg - Exp26 - Annual
# Best Threshold=0.374471
# F-Score=0.767
# Tensile Strength: 113.18 kPa
# ILAvg - Exp26 - DJF
# Best Threshold=0.391094
# F-Score=0.771
# Tensile Strength: 171.15 kPa
# ILAvg - Exp26 - JJA
# Best Threshold=0.394741
# F-Score=0.768
# Tensile Strength: 59.978 kPa
# ILAvg - Exp27 - Decadal
# Best Threshold=0.407613
# F-Score=0.766
# Tensile Strength: 112.681 kPa
# ILAvg - Exp27 - Annual
# Best Threshold=0.401584
# F-Score=0.768
# Tensile Strength: 114.472 kPa
# ILAvg - Exp27 - DJF
# Best Threshold=0.406963
# F-Score=0.766
# Tensile Strength: 171.625 kPa
# ILAvg - Exp27 - JJA
# Best Threshold=0.401738
# F-Score=0.765
# Tensile Strength: 59.541 kPa
# ILAvg - Exp28 - Decadal
# Best Threshold=0.400330
# F-Score=0.755
# Tensile Strength: 110.561 kPa
# ILAvg - Exp28 - Annual
# Best Threshold=0.393478
# F-Score=0.757
# Tensile Strength: 112.4 kPa
# ILAvg - Exp28 - DJF
# Best Threshold=0.391622
# F-Score=0.759
# Tensile Strength: 167.158 kPa
# ILAvg - Exp28 - JJA
# Best Threshold=0.411450
# F-Score=0.755
# Tensile Strength: 59.41 kPa

# %% [markdown]
# ## [4] Save the Results of the Parameter Optimization

# %%
import pickle
with open('Optimization_MapA.pickle', 'wb') as handle:
    pickle.dump(f1_results, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## [5] Plot the Results of the Parameter Optimization
#
# This code can be used to reproduce Figure 3 (Map A) and Figure S4 (Map B).

# %%
# Note: max F1 score for Map A = 0.858
# max F1 score for Map B = 0.842

from matplotlib.collections import LineCollection

import pickle
with open('./data/Optimization_MapA.pickle', 'rb') as f:
    f1_results = pickle.load(f)

box = np.array([1500, 2500, 3500, 4500, 5500, 6500, 7500])
gauss = np.array([250, 500, 750, 1000, 1250, 1500, 1750])
thick = np.array([1, 2, 3, 4, 5, 6, 7])

scale = np.array([5,4,3,2,1])

fig, axs = plt.subplots(2,2, layout="constrained", figsize=(10,7))

# Generate line collection
MAvg_lines = []
M12_lines = []
ILAvg_lines = []
for i in range(f1_results.shape[2]):
    MAvg_lines.append(np.concatenate((box.reshape(-1,1), f1_results[0,0:7,i].reshape(-1,1)), axis=1))
    M12_lines.append(np.concatenate((box.reshape(-1,1), f1_results[1,0:7,i].reshape(-1,1)), axis=1))
    ILAvg_lines.append(np.concatenate((box.reshape(-1,1), f1_results[2,0:7,i].reshape(-1,1)), axis=1))
MAvg_coll = LineCollection(MAvg_lines, array=scale, cmap="Oranges")
M12_coll = LineCollection(M12_lines, array=scale, cmap="Greys")
ILAvg_coll = LineCollection(ILAvg_lines, array=scale, cmap="Blues")
axs[0, 0].add_collection(M12_coll)
axs[0, 0].add_collection(MAvg_coll)
axs[0, 0].add_collection(ILAvg_coll)
for i in range(f1_results.shape[2]):
    axs[0,0].scatter(box, f1_results[1,0:7,i], color="#777777", s=10, zorder=3, edgecolors='black')
    axs[0,0].scatter(box, f1_results[0,0:7,i], color="#bc1b78", s=10, zorder=3, edgecolors='black')
    axs[0,0].scatter(box, f1_results[2,0:7,i], color="#0a7a9f", s=10, zorder=3, edgecolors='black')
axs[0, 0].plot(box, 0.858*np.ones(box.shape), color="black", linestyle="dashed")
axs[0, 0].set_ylim((0.70, 0.87))
axs[0, 0].set_xlabel("Kernel Width (m)")
axs[0, 0].set_ylabel("F1 Score")
axs[0, 0].set_title("Box Filter")

MAvg_lines = []
M12_lines = []
ILAvg_lines = []
for i in range(f1_results.shape[2]):
    MAvg_lines.append(np.concatenate((box.reshape(-1,1), f1_results[0,7:14,i].reshape(-1,1)), axis=1))
    M12_lines.append(np.concatenate((box.reshape(-1,1), f1_results[1,7:14,i].reshape(-1,1)), axis=1))
    ILAvg_lines.append(np.concatenate((box.reshape(-1,1), f1_results[2,7:14,i].reshape(-1,1)), axis=1))
MAvg_coll = LineCollection(MAvg_lines, array=scale, cmap="Oranges")
M12_coll = LineCollection(M12_lines, array=scale, cmap="Greys")
ILAvg_coll = LineCollection(ILAvg_lines, array=scale, cmap="Blues")
axs[0, 1].add_collection(M12_coll)
axs[0, 1].add_collection(MAvg_coll)
axs[0, 1].add_collection(ILAvg_coll)
for i in range(f1_results.shape[2]):
    axs[0,1].scatter(box, f1_results[1,7:14,i], color="#777777", s=10, zorder=3, edgecolors='black')
    axs[0,1].scatter(box, f1_results[0,7:14,i], color="#bc1b78", s=10, zorder=3, edgecolors='black')
    axs[0,1].scatter(box, f1_results[2,7:14,i], color="#0a7a9f", s=10, zorder=3, edgecolors='black')
axs[0, 1].plot(box, 0.858*np.ones(box.shape), color="black", linestyle="dashed")
axs[0, 1].set_ylim((0.70, 0.87))
axs[0, 1].set_xlabel("Kernel Width (m)")
axs[0, 1].set_ylabel("F1 Score")
axs[0, 1].set_title("Triangular Filter")

MAvg_lines = []
M12_lines = []
ILAvg_lines = []
for i in range(f1_results.shape[2]):
    MAvg_lines.append(np.concatenate((gauss.reshape(-1,1), f1_results[0,14:21,i].reshape(-1,1)), axis=1))
    M12_lines.append(np.concatenate((gauss.reshape(-1,1), f1_results[1,14:21,i].reshape(-1,1)), axis=1))
    ILAvg_lines.append(np.concatenate((gauss.reshape(-1,1), f1_results[2,14:21,i].reshape(-1,1)), axis=1))
MAvg_coll = LineCollection(MAvg_lines, array=scale, cmap="Oranges")
M12_coll = LineCollection(M12_lines, array=scale, cmap="Greys")
ILAvg_coll = LineCollection(ILAvg_lines, array=scale, cmap="Blues")
axs[1, 0].add_collection(M12_coll)
axs[1, 0].add_collection(MAvg_coll)
axs[1, 0].add_collection(ILAvg_coll)
for i in range(f1_results.shape[2]):
    axs[1,0].scatter(gauss, f1_results[1,14:21,i], color="#777777", s=10, zorder=3, edgecolors='black')
    axs[1,0].scatter(gauss, f1_results[0,14:21,i], color="#bc1b78", s=10, zorder=3, edgecolors='black')
    axs[1,0].scatter(gauss, f1_results[2,14:21,i], color="#0a7a9f", s=10, zorder=3, edgecolors='black')
axs[1, 0].plot(gauss, 0.858*np.ones(box.shape), color="black", linestyle="dashed")
axs[1, 0].set_ylim((0.70, 0.87))
axs[1, 0].set_xlabel("$\sigma$ (m)")
axs[1, 0].set_ylabel("F1 Score")
axs[1, 0].set_title("Gaussian Filter")

MAvg_lines = []
M12_lines = []
ILAvg_lines = []
for i in range(f1_results.shape[2]):
    MAvg_lines.append(np.concatenate((thick.reshape(-1,1), f1_results[0,21:28,i].reshape(-1,1)), axis=1))
    M12_lines.append(np.concatenate((thick.reshape(-1,1), f1_results[1,21:28,i].reshape(-1,1)), axis=1))
    ILAvg_lines.append(np.concatenate((thick.reshape(-1,1), f1_results[2,21:28,i].reshape(-1,1)), axis=1))
MAvg_coll = LineCollection(MAvg_lines, array=scale, cmap="Oranges")
M12_coll = LineCollection(M12_lines, array=scale, cmap="Greys")
ILAvg_coll = LineCollection(ILAvg_lines, array=scale, cmap="Blues")
axs[1, 1].add_collection(M12_coll)
axs[1, 1].add_collection(MAvg_coll)
axs[1, 1].add_collection(ILAvg_coll)
for i in range(f1_results.shape[2]):
    axs[1,1].scatter(thick, f1_results[1,21:28,i], color="#777777", s=10, zorder=3, edgecolors='black')
    axs[1,1].scatter(thick, f1_results[0,21:28,i], color="#bc1b78", s=10, zorder=3, edgecolors='black')
    axs[1,1].scatter(thick, f1_results[2,21:28,i], color="#0a7a9f", s=10, zorder=3, edgecolors='black')
axs[1, 1].plot(thick, 0.858*np.ones(box.shape), color="black", linestyle="dashed")
axs[1, 1].set_ylim((0.70, 0.87))
axs[1, 1].set_xlabel("Ice Thickness Multiplier")
axs[1, 1].set_ylabel("F1 Score")
axs[1, 1].set_title("Ice Thickness Dependent Smoothing")

plt.savefig("C:\\Users\\rtc84\OneDrive - Cornell University\\Research_FirstAuthor\\IceSlabCrevasses\\Revision\\RevisedFigures\\Optimization_MapA.svg")
plt.show()

# %% [markdown]
# ### Equate F1 Score to Correct Area
#
# This block of code calculates the fraction of the test area that was correctly classified for each case in shown in the figure above. This gives a more intuitive sense of what the improvement in F1 score between the GIMP and ITS_LIVE velocities actually means.

# %%
# List of strain map experiment names
strain_experiments = ["Exp1", "Exp2", "Exp3", "Exp4", "Exp5", "Exp6", "Exp7", 
                      "Exp8", "Exp9", "Exp10", "Exp11", "Exp12", "Exp13", "Exp14", 
                      "Exp15", "Exp16", "Exp17", "Exp18", "Exp19", "Exp20", "Exp21",
                      "Exp22", "Exp23", "Exp24", "Exp25", "Exp26", "Exp27", "Exp28"]
# List of velocity sources to test
velocity_maps = ["MAvg", "M12", "ILAvg"]
# List of temperature average time periods to test
temp_maps = ["Decadal", "Annual", "DJF", "JJA"]

ca_MAvg = []
ca_ILAvg = []
f1_diff = []
a = velocity_maps.index("MAvg")
for k in strain_experiments:
    for j in temp_maps:
        a_prime = velocity_maps.index("ILAvg")
        b = strain_experiments.index(k)
        c = temp_maps.index(j)
        ca_MAvg.append((tp_results[a,b,c] + tn_results[a,b,c])/(tp_results[a,b,c] + tn_results[a,b,c] + fp_results[a,b,c] + fn_results[a,b,c]))
        f1_diff.append(f1_results[a,b,c] - f1_results[a_prime,b,c])

a = velocity_maps.index("ILAvg")
for k in strain_experiments:
    for j in temp_maps:
        b = strain_experiments.index(k)
        c = temp_maps.index(j)
        ca_ILAvg.append((tp_results[a,b,c] + tn_results[a,b,c])/(tp_results[a,b,c] + tn_results[a,b,c] + fp_results[a,b,c] + fn_results[a,b,c]))

ca_MAvg = np.array(ca_MAvg)
ca_ILAvg = np.array(ca_ILAvg)
f1_diff = np.array(f1_diff)

plt.close("all")
plt.scatter(f1_diff, ca_MAvg - ca_ILAvg)
plt.plot(np.arange(0,0.07,0.001), np.arange(0,0.07,0.001), ":k")
plt.xlabel("Difference in F1 Score")
plt.ylabel("Difference in Correctly Classified Area")
plt.show()

print("Maximum difference in correctly classified area: ", np.max(ca_MAvg - ca_ILAvg))
print("Maximum difference in F1 score", f1_diff[np.argmax(f1_diff)])
print("Difference in correctly classified area for maximum difference in F1 score: ", np.max(ca_MAvg[np.argmax(f1_diff)] - ca_ILAvg[np.argmax(f1_diff)]))
# Out:
# 0.06594478997826991
# 7
# 0.06713817538289124
# 0.06594478997826991

# %% [markdown]
# ## [6] Confusion Matrix for Example Model
#
# To run this section, edit Section 3 to train a single model of interest instead of the entire optimization ensemble. Then run this code block. This can be used to reproduce Figure S7.

# %%
metrics.ConfusionMatrixDisplay.from_predictions(y_test, y_hat, normalize='true', cmap="autumn", display_labels = ["crevassed", "uncrevassed"])
plt.yticks(rotation =90)
plt.savefig("C:\\Users\\rtc84\OneDrive - Cornell University\\Research_FirstAuthor\\IceSlabCrevasses\\Revision\\RevisedFigures\\ConfusionMatrix_MapA.svg")
plt.show()

# %% [markdown]
# ## [7] Regional Cross-Validation
#
# This code runs a five-fold regional cross-validation using the optimal method of calculating stresses. This is "Experiment 18", which used the MEASURES multi-decadal average velocities smoothed using a Gaussian filter with a 1000 m bandwidth, the Cuffey & Patterson rate factor parameterization, and the mean anuual RACMO surface temperatures. Regional folds are defined as in Figure 1 of the main text.

# %%
strain_dir_w = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\StrainRate\\"
strain_dir_e = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\StrainRateNE\\"
temp_dir = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\RACMOTraining\\"
crev_dir = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\RevisedTrainingData\\"
test_dir =  "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\TestSet\\"
val_dir = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\TestSet\\"

strain_experiments = ["Exp17"]
velocity_maps = ["MAvg"]
temp_maps = ["Annual"]

# Define the crevasse observations you want to use for training
crev_map = "MapA"

# Cuffey and Patterson Constants for Ice Viscosity Model
A_star = 3.5e-25        # Pa^-3s^-1
T_start = 263.0         # K
R = 8.314               # J mol^-1 K^-1
Qc = 60e3               # J mol^-1
Qc2 = 115e3             # J mol^-1
n = 3.

# Cross-validation parameters
n_folds = 5

f1_crossval = np.zeros(n_folds)
for i in velocity_maps:
    for j in strain_experiments:
        # Set file locations for the strain rate for the west coast
        eXX_file_w = strain_dir_w+j+"_eXX_"+i+".tif"
        eYY_file_w = strain_dir_w+j+"_eYY_"+i+".tif"
        eXY_file_w = strain_dir_w+j+"_eXY_"+i+".tif"

        # Read in all three components of the strain rate for the west coast
        dataset = rio.open(eXX_file_w)
        eXX_w = dataset.read(1)
        dataset.close()
        dataset = rio.open(eYY_file_w)
        eYY_w = dataset.read(1)
        dataset.close()
        dataset = rio.open(eXY_file_w)
        eXY_w = dataset.read(1)
        dataset.close()

        # Set file locations for the strain rate for the east coast
        eXX_file_e = strain_dir_e+j+"_eXX_"+i+".tif"
        eYY_file_e = strain_dir_e+j+"_eYY_"+i+".tif"
        eXY_file_e = strain_dir_e+j+"_eXY_"+i+".tif"

        # Read in all three components of the strain rate for the east coast
        dataset = rio.open(eXX_file_e)
        eXX_e = dataset.read(1)
        dataset.close()
        dataset = rio.open(eYY_file_e)
        eYY_e = dataset.read(1)
        dataset.close()
        dataset = rio.open(eXY_file_e)
        eXY_e = dataset.read(1)
        dataset.close()

        # Mask out regions of no data in the 2012-2013 strain rate maps
        if i == "M12":
            eXX_w = eXX_w*vel_mask_w
            eYY_w = eYY_w*vel_mask_w
            eXY_w = eXY_w*vel_mask_w
            eXX_e = eXX_e*vel_mask_e
            eYY_e = eYY_e*vel_mask_e
            eXY_e = eXY_e*vel_mask_e

        for k in temp_maps:
            # Find the desired temperature field at the appropriate resolution
            if i == "MAvg":
                temp_file_w = temp_dir+"Clip_RACMO"+k+"_250m.tif"
                temp_file_e = temp_dir+"NE_RACMO"+k+"_250m.tif"
                crev_file_w = crev_dir+"CrevasseMask_250m_"+crev_map+".tif"
                crev_file_e = crev_dir+"NE_CrevasseMask_250m_"+crev_map+".tif"
                nocrev_file_w = crev_dir+"NoCrevasseMask_250m_"+crev_map+".tif"
                nocrev_file_e = crev_dir+"NE_NoCrevasseMask_250m_"+crev_map+".tif"
                test_file_e = test_dir+"NE_TestSet_250m.tif"
                test_file_w = test_dir+"W_TestSet_250m.tif"
                val_file_e =  test_dir+"NE_KFold_250m.tif"
                val_file_w =  test_dir+"W_KFold_250m.tif"
            elif i == "M12":
                temp_file_w = temp_dir+"Clip_RACMO"+k+"_500m.tif"
                temp_file_e = temp_dir+"NE_RACMO"+k+"_500m.tif"
                crev_file_w = crev_dir+"CrevasseMask_500m_"+crev_map+".tif"
                crev_file_e = crev_dir+"NE_CrevasseMask_500m_"+crev_map+".tif"
                nocrev_file_w = crev_dir+"NoCrevasseMask_Full_500m_"+crev_map+".tif"
                nocrev_file_e = crev_dir+"NE_NoCrevasseMask_500m_"+crev_map+".tif"
                test_file_e = test_dir+"NE_TestSet_500m.tif"
                test_file_w = test_dir+"W_TestSet_500m.tif"
                val_file_e =  test_dir+"NE_KFold_500m.tif"
                val_file_w =  test_dir+"W_KFold_500m.tif"
            elif i == "ILAvg":
                temp_file_w = temp_dir+"Clip_RACMO"+k+"_240m.tif"
                temp_file_e = temp_dir+"NE_RACMO"+k+"_240m.tif"
                crev_file_w = crev_dir+"CrevasseMask_240m_"+crev_map+".tif"
                crev_file_e = crev_dir+"NE_CrevasseMask_240m_"+crev_map+".tif"
                nocrev_file_w = crev_dir+"NoCrevasseMask_240m_"+crev_map+".tif"
                nocrev_file_e = crev_dir+"NE_NoCrevasseMask_240m_"+crev_map+".tif"
                test_file_e = test_dir+"NE_TestSet_240m.tif"
                test_file_w = test_dir+"W_TestSet_240m.tif"
                val_file_e =  test_dir+"NE_KFold_240m.tif"
                val_file_w =  test_dir+"W_KFold_240m.tif"

            # Load data for the west coast temperature field
            dataset = rio.open(temp_file_w)
            temp_w = dataset.read(1)
            dataset.close()
            # Load crevasse mask for west coast
            dataset = rio.open(crev_file_w)
            crevasses_w = dataset.read(1)
            dataset.close()
            # Load no crevasse mask for west coast
            dataset = rio.open(nocrev_file_w)
            no_crevasses_w = dataset.read(1)
            dataset.close()
            # Load test set for west coast
            dataset = rio.open(test_file_w)
            test_w = dataset.read(1)
            dataset.close()
            # Load cross validation test sets for west coast
            dataset = rio.open(val_file_w)
            val_w = dataset.read(1)
            dataset.close()

            # Load data for the east coast temperature field
            dataset = rio.open(temp_file_e)
            temp_e = dataset.read(1)
            dataset.close()
            # Load crevasse mask for east coast
            dataset = rio.open(crev_file_e)
            crevasses_e = dataset.read(1)
            dataset.close()
            # Load no crevasse mask for east coast
            dataset = rio.open(nocrev_file_e)
            no_crevasses_e = dataset.read(1)
            dataset.close()
             # Load test set for east coast
            dataset = rio.open(test_file_e)
            test_e = dataset.read(1)
            dataset.close()
             # Load cross validation test sets for east coast
            dataset = rio.open(val_file_e)
            val_e = dataset.read(1)
            dataset.close()

            crevasses_w = np.matrix.flatten(crevasses_w.astype("float64"))
            crevasses_e = np.matrix.flatten(crevasses_e.astype("float64"))
            crevasses = np.concatenate((crevasses_w, crevasses_e), axis=0)
            no_crevasses_w = np.matrix.flatten(no_crevasses_w.astype("float64"))
            no_crevasses_e = np.matrix.flatten(no_crevasses_e.astype("float64"))
            no_crevasses = np.concatenate((no_crevasses_w, no_crevasses_e), axis=0)
            test_w = np.matrix.flatten(test_w.astype("float64"))
            test_e = np.matrix.flatten(test_e.astype("float64"))
            test = np.concatenate((test_w, test_e), axis=0)
            val_w = np.matrix.flatten(val_w.astype("float64"))
            val_e = np.matrix.flatten(val_e.astype("float64"))
            val = np.concatenate((val_w, val_e), axis=0)

            # Combine flattened strain rate matrices for both regions (east and west)
            eXX_comb = np.concatenate((np.matrix.flatten(eXX_w), np.matrix.flatten(eXX_e)), axis=0)
            eXY_comb = np.concatenate((np.matrix.flatten(eXY_w), np.matrix.flatten(eXY_e)), axis=0)
            eYY_comb = np.concatenate((np.matrix.flatten(eYY_w), np.matrix.flatten(eYY_e)), axis=0)

            # Combine flattened temperature information for both regions (east and west)
            temp_comb = np.concatenate((np.matrix.flatten(temp_w), np.matrix.flatten(temp_e)), axis=0)

            # Extract strain rates in crevassed and uncrevassed regions
            eXX_crev = eXX_comb[crevasses == 1]
            eXX_nocrev = eXX_comb[no_crevasses == 1]
            eXY_crev = eXY_comb[crevasses == 1]
            eXY_nocrev = eXY_comb[no_crevasses == 1]
            eYY_crev = eYY_comb[crevasses == 1]
            eYY_nocrev = eYY_comb[no_crevasses == 1]

            # Extract temperatures for crevassed and uncrevassed regions
            temp_crev = temp_comb[crevasses == 1]
            temp_nocrev = temp_comb[no_crevasses == 1]

            # Extract test set for crevassed and uncrevassed regions
            test_crev = test[crevasses == 1]
            test_nocrev = test[no_crevasses == 1]

            # Extract cross=validation set for crevassed and uncrevassed regions
            val_crev = val[crevasses == 1]
            val_nocrev = val[no_crevasses == 1]

            # Merge into a single vectors for all variables of interest
            eXX = np.concatenate((eXX_crev, eXX_nocrev), axis=0)
            eXY = np.concatenate((eXY_crev, eXY_nocrev), axis=0)
            eYY = np.concatenate((eYY_crev, eYY_nocrev), axis=0)
            temp = np.concatenate((temp_crev,  temp_nocrev), axis=0)
            test_set = np.concatenate((test_crev,  test_nocrev), axis=0)
            val_set = np.concatenate((val_crev, val_nocrev), axis=0)

            # Convert temperature field to degrees Kelvin
            temp = temp + 273.15

            # Calculate creep coefficient with temperature dependence of activation energy on west coast
            A = np.zeros(temp.shape)
            for p in range(0,temp.shape[0]):
                if temp[p] > 273.15:
                    temp[p] = 273.15
                    A[p] = A_star*np.exp((-Qc2/R)*((1/temp[p]) - (1/T_start)))
                elif temp[p] > 263.0:
                    A[p] = A_star*np.exp((-Qc2/R)*((1/temp[p]) - (1/T_start)))
                else:
                    A[p] = A_star*np.exp((-Qc/R)*((1/temp[p]) - (1/T_start)))

            # Convert strain rates from 1/yr to 1/s
            eXX_s = eXX*(1/(60*60*24*365))
            eXY_s = eXY*(1/(60*60*24*365))
            eYY_s = eYY*(1/(60*60*24*365))

            #Calculate effective stress
            eE = np.sqrt(0.5*(eXX_s**2 + eYY_s**2 + (-eXX_s - eYY_s)**2) + eXY_s**2)

            # Calculate deviatoric stress at surface
            tau_xx = (A**(-1/n))*(eE**((1-n)/n))*eXX_s
            tau_yy = (A**(-1/n))*(eE**((1-n)/n))*eYY_s
            tau_xy = (A**(-1/n))*(eE**((1-n)/n))*eXY_s 

            # Calculate full Cauchy stress at surface
            sigma_xx = 2.*tau_xx + tau_yy
            sigma_yy = 2.*tau_yy + tau_xx

            # Calculate principal stresses
            sigma1 = 0.5*(sigma_xx + sigma_yy) + np.sqrt((0.5*(sigma_xx - sigma_yy))**2 + tau_xy**2)
            sigma2 = 0.5*(sigma_xx + sigma_yy) - np.sqrt((0.5*(sigma_xx - sigma_yy))**2 + tau_xy**2)

            # Von Mises Stress over whole area of interest
            sigmaV = np.sqrt(sigma1**2 - sigma1*sigma2 + sigma2**2)

            # Make the label set
            label = np.concatenate((np.ones(temp_crev.shape), np.zeros(temp_nocrev.shape)), axis=0)

            # Remove regions of pure compression, because we will automatically predict no fracture there
            stress = sigmaV[sigma1 > 0.]
            test_set = test_set[sigma1 > 0.]
            val_set = val_set[sigma1 > 0.]
            compression_label = label[sigma1 <= 0.]
            label = label[sigma1 > 0.]
            
            # Clean up edge case problems for the M12 data with a bunch of gaps
            if i == "M12":
                val_set = val_set[stress < 500000.]
                test_set = test_set[stress < 500000.]
                label = label[stress < 500000.]
                stress = stress[stress < 500000.]

            for k in range(0, n_folds):
                test_fold = np.copy(val_set) 
                test_fold[test_fold < k+1] = 0
                test_fold[test_fold > k+1] = 0
                test_fold[test_fold == k+1] = 1

                #print(test_fold[test_fold == 0].shape)
                #print(test_fold[test_fold == 1].shape)
                
                # Test-train split once optimized
                #stress_train,stress_test,label_train,label_test=train_test_split(stress.reshape(-1,1),label,stratify=test_fold)

                stress_train = stress[test_fold == 0].reshape(-1,1)
                stress_test = stress[test_fold == 1].reshape(-1,1)
                label_train = label[test_fold == 0]
                label_test = label[test_fold == 1]
            
                regress = LogisticRegression(class_weight="balanced")
                regress.fit(stress_train,label_train)
            
                prob = regress.predict_proba(stress_train)
                precision, recall, thresholds = metrics.precision_recall_curve(label_train, prob[:,1])
                # convert to f score
                fscore = (2 * precision * recall) / (precision + recall)
                fscore[np.isnan(fscore)] = 0
                # locate the index of the largest f score
                ix = np.argmax(fscore)
                print('Best Threshold=%f' % (thresholds[ix]))
                

                # Calculate crevasse predictions on test set with optimized discrimination threshold
                prob = regress.predict_proba(stress_test)
                y_hat = np.zeros(prob[:,1].shape)
                y_hat[prob[:,1] >= thresholds[ix]] = 1
                # Reincorporate regions of pure compression which we automatically assign to be no crevasse
                y_hat = np.concatenate((y_hat, np.zeros(compression_label.shape)), axis=0)
                y_test = np.concatenate((label_test, compression_label), axis=0)
                fscore = metrics.f1_score(y_test, y_hat, average="weighted") 
                accuracy = metrics.balanced_accuracy_score(y_test, y_hat)
                mcc = metrics.matthews_corrcoef(y_test, y_hat)
                print('Fold # %.1f F-Score=%.3f\n' % (k, fscore))
                print('Fold # %.1f Balanced Accuracy=%.3f' % (k, accuracy))

                axis = np.arange(20000,250000,1).reshape(-1,1)
                probability = regress.predict_proba(axis)
                ind = np.argmin(np.abs(probability[:,1] - thresholds[ix]))
                print("Tensile Strength: "+str(axis[ind,0]/1000.)+" kPa")

                # metrics.ConfusionMatrixDisplay.from_predictions(y_test, y_hat, normalize='true', cmap="autumn")
                # plt.show()
                
                f1_crossval[k] = fscore
# Out:
# Best Threshold=0.307098
# Fold # 0.0 F-Score=0.866
# Fold # 0.0 Ballanced Accuracy=0.812
# Tensile Strength: 102.762 kPa
# Best Threshold=0.385469
# Fold # 1.0 F-Score=0.839
# Fold # 1.0 Ballanced Accuracy=0.836
# Tensile Strength: 106.771 kPa
# Best Threshold=0.389678
# Fold # 2.0 F-Score=0.842
# Fold # 2.0 Ballanced Accuracy=0.839
# Tensile Strength: 108.307 kPa
# Best Threshold=0.341823
# Fold # 3.0 F-Score=0.798
# Fold # 3.0 Ballanced Accuracy=0.777
# Tensile Strength: 108.546 kPa
# Best Threshold=0.289478
# Fold # 4.0 F-Score=0.795
# Fold # 4.0 Ballanced Accuracy=0.604
# Tensile Strength: 109.09 kPa
