# %% [markdown]
# ## [1] Import Libraries

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sklearn
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn import metrics
import rasterio as rio
import pickle
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## [2] Calculate Baseline Tensile Strengths
#
# This section calculates the tensile strength as a function of the surface temperature model, averaging time period, and rate factor parameterization without considering velocity error. This provides a baseline that we use for plotting the black dots in Figure 4.

# %%
##### Baseline Tensile Strength Estimate Variations

# Directories with the strain rates
strain_dir_w = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\StrainRate\\"
strain_dir_e = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\StrainRateNE\\"
# Directory with the surface temperatures
temp_dir = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\"
# Directory with the crevasse/no crevasse observations
crev_dir = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\TrainingData\\"
# Directory with the boundaries of the test data that we will withold from training
test_dir =  "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\TestSet\\"

# Baseline (optimal) strain rate map to sue
strain_experiments = "Exp18"
# Baseline (optimal) velocity data source to use
velocity_maps = "MAvg"
# List of temperature averaging options to test
temp_maps = ["Annual", "DJF"]
# List of temperature models to test
temp_model = ["RACMO", "MAR", "CARRA"]
# List of rate factor parameterizations to try, 0 = Cuffey & Patterson, 1 = Hooke
viscosity = [0, 1]

# Cuffey and Patterson Constants for Ice Viscosity Model
A_star = 3.5e-25        # Pa^-3s^-1
T_start = 263.0         # K
R = 8.314               # J mol^-1 K^-1
Qc = 60e3               # J mol^-1
Qc2 = 115e3             # J mol^-1
n = 3.

# Hooke Viscosity Model Parameters
B0 = 2.207     # Pa year^-1
T0 = 3155                 # K
C = 0.16612               # K^k
T_r = 273.39              # K
k = 1.17

# Probability axis
axis = np.arange(0,350000,100).reshape(-1,1)

count = 0

# Save the optimal discrmination threshold probability
threshold = np.zeros((len(temp_maps),len(temp_model),len(viscosity)))
# Save the optimized tensile strength
tensile_strength = np.zeros((len(temp_maps),len(temp_model),len(viscosity)))
# Save the full probability of fracture curve for each model
prob_curve = np.zeros((len(axis),len(temp_maps)*len(temp_model)*len(viscosity)))
for i in temp_maps:
    for j in temp_model:
        for k in viscosity:
            
            # Strain files for west coast
            eXX_file_w = strain_dir_w+strain_experiments+"_eXX_"+velocity_maps+".tif"
            eYY_file_w = strain_dir_w+strain_experiments+"_eYY_"+velocity_maps+".tif"
            eXY_file_w = strain_dir_w+strain_experiments+"_eXY_"+velocity_maps+".tif"

            # Read in all three components of the strain rate
            dataset = rio.open(eXX_file_w)
            eXX_w = dataset.read(1)
            dataset.close()
            dataset = rio.open(eYY_file_w)
            eYY_w = dataset.read(1)
            dataset.close()
            dataset = rio.open(eXY_file_w)
            eXY_w = dataset.read(1)
            dataset.close()

             # Strain files for east coast
            eXX_file_e = strain_dir_e+strain_experiments+"_eXX_"+velocity_maps+".tif"
            eYY_file_e = strain_dir_e+strain_experiments+"_eYY_"+velocity_maps+".tif"
            eXY_file_e = strain_dir_e+strain_experiments+"_eXY_"+velocity_maps+".tif"

            # Read in all three components of the strain rate
            dataset = rio.open(eXX_file_e)
            eXX_e = dataset.read(1)
            dataset.close()
            dataset = rio.open(eYY_file_e)
            eYY_e = dataset.read(1)
            dataset.close()
            dataset = rio.open(eXY_file_e)
            eXY_e = dataset.read(1)
            dataset.close()
            
            temp_file_w = temp_dir+j+"Training\\Clip_"+j+i+"_250m.tif"
            temp_file_e = temp_dir+j+"Training\\NE_"+j+i+"_250m.tif"
            crev_file_w = crev_dir+"Clip_CrevasseMask_250m.tif"
            crev_file_e = crev_dir+"NE_CrevasseMask_250m.tif"
            nocrev_file_w = crev_dir+"Clip_NoCrevasseMask_Full_250m.tif"
            nocrev_file_e = crev_dir+"NE_NoCrevasseMask_250m.tif"
            test_file_w = test_dir+"W_TestSet_250m.tif"
            test_file_e = test_dir+"NE_TestSet_250m.tif"
                    
            # Load data for the west coast temperature filed
            dataset = rio.open(temp_file_w)
            temp_w = dataset.read(1)
            dataset.close()
            # Load crevasse mask for west coast
            dataset = rio.open(crev_file_w)
            crevasses_w = dataset.read(1)
            dataset.close()
            # Load no crevasse mask for west coast
            dataset = rio.open(nocrev_file_w)
            no_crevasses_w = dataset.read(1)
            dataset.close()
            # Load test set for west coast
            dataset = rio.open(test_file_w)
            test_w = dataset.read(1)
            dataset.close()

            # Load data for the east coast temperature field
            dataset = rio.open(temp_file_e)
            temp_e = dataset.read(1)
            dataset.close()
            # Load crevasse mask for east coast
            dataset = rio.open(crev_file_e)
            crevasses_e = dataset.read(1)
            dataset.close()
            # Load no crevasse mask for east coast
            dataset = rio.open(nocrev_file_e)
            no_crevasses_e = dataset.read(1)
            dataset.close()
            # Load test set for east coast
            dataset = rio.open(test_file_e)
            test_e = dataset.read(1)
            dataset.close()

             # File paths for the appropriate temperature fields, crevassse observations, and test set mask
            crevasses_w = np.matrix.flatten(crevasses_w.astype("float64"))
            crevasses_e = np.matrix.flatten(crevasses_e.astype("float64"))
            crevasses = np.concatenate((crevasses_w, crevasses_e), axis=0)
            no_crevasses_w = np.matrix.flatten(no_crevasses_w.astype("float64"))
            no_crevasses_e = np.matrix.flatten(no_crevasses_e.astype("float64"))
            no_crevasses = np.concatenate((no_crevasses_w, no_crevasses_e), axis=0)
            test_w = np.matrix.flatten(test_w.astype("float64"))
            test_e = np.matrix.flatten(test_e.astype("float64"))
            test = np.concatenate((test_w, test_e), axis=0)

            # Combine flattened strain rate matrices for both regions (east and west)
            eXX_comb = np.concatenate((np.matrix.flatten(eXX_w), np.matrix.flatten(eXX_e)), axis=0)
            eXY_comb = np.concatenate((np.matrix.flatten(eXY_w), np.matrix.flatten(eXY_e)), axis=0)
            eYY_comb = np.concatenate((np.matrix.flatten(eYY_w), np.matrix.flatten(eYY_e)), axis=0)

            # Combine flattened temperature information for both regions (east and west)
            temp_comb = np.concatenate((np.matrix.flatten(temp_w), np.matrix.flatten(temp_e)), axis=0)

            # Extract strain rates in crevassed and uncrevassed regions
            eXX_crev = eXX_comb[crevasses == 1]
            eXX_nocrev = eXX_comb[no_crevasses == 1]
            eXY_crev = eXY_comb[crevasses == 1]
            eXY_nocrev = eXY_comb[no_crevasses == 1]
            eYY_crev = eYY_comb[crevasses == 1]
            eYY_nocrev = eYY_comb[no_crevasses == 1]

            # Extract temperatures for crevassed and uncrevassed regions
            temp_crev = temp_comb[crevasses == 1]
            temp_nocrev = temp_comb[no_crevasses == 1]

            # Extract test set for crevassed and uncrevassed regions
            test_crev = test[crevasses == 1]
            test_nocrev = test[no_crevasses == 1]

            # Merge into a single vectors for all variables of interest
            eXX = np.concatenate((eXX_crev, eXX_nocrev), axis=0)
            eXY = np.concatenate((eXY_crev, eXY_nocrev), axis=0)
            eYY = np.concatenate((eYY_crev, eYY_nocrev), axis=0)
            temp = np.concatenate((temp_crev,  temp_nocrev), axis=0)
            test_set = np.concatenate((test_crev,  test_nocrev), axis=0)

            # Convert temperature field to degrees Kelvin
            temp = temp + 273.15

            if k == 0:   # Cuffey and Patterson rate factor
                # Calculate creep coefficient with temperature dependence of activation energy
                A = np.zeros(temp.shape)
                for p in range(0,temp.shape[0]):
                    if temp[p] > 273.15:
                        temp[p] = 273.15
                        A[p] = A_star*np.exp((-Qc2/R)*((1/temp[p]) - (1/T_start)))
                    elif temp[p] > 263.0:
                        A[p] = A_star*np.exp((-Qc2/R)*((1/temp[p]) - (1/T_start)))
                    else:
                        A[p] = A_star*np.exp((-Qc/R)*((1/temp[p]) - (1/T_start)))
                # Convert strain rates from 1/yr to 1/s
                eXX_s = eXX*(1/(60*60*24*365))
                eXY_s = eXY*(1/(60*60*24*365))
                eYY_s = eYY*(1/(60*60*24*365))
                #Calculate effective stress
                eE = np.sqrt(0.5*(eXX_s**2 + eYY_s**2 + (-eXX_s - eYY_s)**2) + eXY_s**2)
                # Calculate deviatoric stress at surface
                tau_xx = (A**(-1/n))*(eE**((1-n)/n))*eXX_s
                tau_yy = (A**(-1/n))*(eE**((1-n)/n))*eYY_s
                tau_xy = (A**(-1/n))*(eE**((1-n)/n))*eXY_s  
            elif k == 1:   # Hooke rate factor
                B = np.zeros(temp.shape)
                for p in range(0,temp.shape[0]):
                    if temp[p] > 273.15:
                        temp[p] = 273.15
                    B[p] = B0*np.exp((T0/temp[p]) - (C/np.power(T_r - temp[p], k)))
                #Calculate effective stress
                eE = np.sqrt(0.5*(eXX**2 + eYY**2 + (-eXX - eYY)**2) + eXY**2)
                # Calculate deviatoric stress at surface
                tau_xx = B*(eE**((1-n)/n))*eXX
                tau_yy = B*(eE**((1-n)/n))*eYY
                tau_xy = B*(eE**((1-n)/n))*eXY

            # Calculate full Cauchy stress at surface
            sigma_xx = 2.*tau_xx + tau_yy
            sigma_yy = 2.*tau_yy + tau_xx

            # Calculate principal stresses
            sigma1 = 0.5*(sigma_xx + sigma_yy) + np.sqrt((0.5*(sigma_xx - sigma_yy))**2 + tau_xy**2)
            sigma2 = 0.5*(sigma_xx + sigma_yy) - np.sqrt((0.5*(sigma_xx - sigma_yy))**2 + tau_xy**2)

            # Von Mises Stress over whole area of interest
            sigmaV = np.sqrt(sigma1**2 - sigma1*sigma2 + sigma2**2)

            # Make the label set
            label = np.concatenate((np.ones(temp_crev.shape), np.zeros(temp_nocrev.shape)), axis=0)

            # Remove regions of pure compression, because we will automatically predict no fracture there
            stress = sigmaV[sigma1 > 0.]
            test_set = test_set[sigma1 > 0.]
            compression_label = label[sigma1 <= 0.]
            label = label[sigma1 > 0.]

            # Test-train split using the pre-defined test set
            stress_train,stress_test,label_train,label_test=train_test_split(stress.reshape(-1,1),label,stratify=test_set)

            # Instantiate and train logistic regression model, accounting for class imbalance
            regress = LogisticRegression(class_weight="balanced")
            regress.fit(stress_train,label_train)

            a = temp_maps.index(i)
            b = temp_model.index(j)
            c = viscosity.index(k)

            print(i,"-",j,"-",k)

            # Find the optimal discrimination threshold
            prob = regress.predict_proba(stress_train)
            precision, recall, thresholds = metrics.precision_recall_curve(label_train, prob[:,1])
            # convert to f score
            fscore = (2 * precision * recall) / (precision + recall)
            fscore[np.isnan(fscore)] = 0
            # locate the index of the largest f score
            ix = np.argmax(fscore)
            print('Best Threshold=%.3f' % (thresholds[ix]))

            threshold[a,b,c] = thresholds[ix]

            # Calculate crevasse predictions on test set with optimized discrimination threshold
            prob = regress.predict_proba(stress_test)
            y_hat = np.zeros(prob[:,1].shape)
            y_hat[prob[:,1] >= thresholds[ix]] = 1
            # Reincorporate regions of pure compression which we automatically assign to be no crevasse
            y_hat = np.concatenate((y_hat, np.zeros(compression_label.shape)), axis=0)
            y_test = np.concatenate((label_test, compression_label), axis=0)
            fscore = metrics.f1_score(y_test, y_hat, average="weighted")
            print('F-Score=%.3f' % (fscore))

            # Calculate the tensile strength at the optimal threshold
            probability = regress.predict_proba(axis)
            prob_curve[:,count] = probability[:,1]
            ind = np.argmin(np.abs(probability[:,1] - thresholds[ix]))
            tensile_strength[a,b,c] = axis[ind,0]
            print("Tensile Strength: "+str(axis[ind,0]/1000.)+" kPa")
        
            count = count + 1

# %% [markdown]
# ## [3] Calculate Range of Tensile Strengths (with Velocity Error)
#
# We now run the same set of experiments using the 20 perturbed velocity maps to quantify how errors in the initial velocity measurments propagate into strain rate errors, stress errors, and by extension, uncertainty in the tensile strength of ice slabs.

# %%
# Directories with the strain rates - note that these now need to include velocity perturbations
strain_dir_w = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\ErrorMaps\\"
strain_dir_e = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\ErrorMaps\\NE\\"
# Directory with the surface temperatures
temp_dir = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\"
# Directory with the crevasse/no crevasse observations
crev_dir = "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\TrainingData\\"
# Directory with the boundaries of the test data that we will withold from training
test_dir =  "C:\\Users\\rtc84\\Documents\\Data\\Greenland\\Crevasses\\IceSlabCrevasseData\\TestSet\\"

# List of velocity perturbation experiment names
strain_experiments = ["Exp0", "Exp1", "Exp2", "Exp3", "Exp4", "Exp5", "Exp6", "Exp7","Exp8", "Exp9"]
# List of covariance structure options
correlation = ["Gaussian", "Exponential"]
# List of temperature averaging options to test
temp_maps = ["Annual", "DJF"]
# List of temperatur models to test
temp_model = ["RACMO", "MAR", "CARRA"]
# List of rate factor parameterizations to try, 0 = Cuffey & Patterson, 1 = Hooke
viscosity = [0, 1]

# Cuffey and Patterson Constants for Ice Viscosity Model
A_star = 3.5e-25        # Pa^-3s^-1
T_start = 263.0         # K
R = 8.314               # J mol^-1 K^-1
Qc = 60e3               # J mol^-1
Qc2 = 115e3             # J mol^-1
n = 3.

# Hooke Viscosity Model Parameters
B0 = 2.207     # Pa year^-1
T0 = 3155                 # K
C = 0.16612               # K^k
T_r = 273.39              # K
k = 1.17

# Probability axis
axis = np.arange(0,350000,100).reshape(-1,1)

count = 0
# Save f1 score for each combination of parameters
f1_err = np.zeros((len(temp_maps),len(temp_model),len(viscosity),len(strain_experiments),len(correlation)))
# Save optimal probability threshold for each combination of parameters
threshold_err = np.zeros((len(temp_maps),len(temp_model),len(viscosity),len(strain_experiments),len(correlation)))
# Save estimated tensile strength score for each combination of parameters
tensile_strength_err = np.zeros((len(temp_maps),len(temp_model),len(viscosity),len(strain_experiments),len(correlation)))
# Save fracture probability as a function f stress for each combination of parameters
prob_curve_err = np.zeros((len(axis),len(temp_maps)*len(temp_model)*len(viscosity)*len(correlation)*len(strain_experiments)))

for i in temp_maps:
    for j in temp_model:
        for k in viscosity:
            for m in strain_experiments:
                for w in correlation:

                    # Strain files for west coast
                    eXX_file_w = strain_dir_w+m+"_eXX_"+w+".tif"
                    eYY_file_w = strain_dir_w+m+"_eYY_"+w+".tif"
                    eXY_file_w = strain_dir_w+m+"_eXY_"+w+".tif"

                    # Read in all three components of the strain rate
                    dataset = rio.open(eXX_file_w)
                    eXX_w = dataset.read(1)
                    dataset.close()
                    dataset = rio.open(eYY_file_w)
                    eYY_w = dataset.read(1)
                    dataset.close()
                    dataset = rio.open(eXY_file_w)
                    eXY_w = dataset.read(1)
                    dataset.close()

                    # Strain files for east coast
                    eXX_file_e = strain_dir_e+m+"_eXX_"+w+".tif"
                    eYY_file_e = strain_dir_e+m+"_eYY_"+w+".tif"
                    eXY_file_e = strain_dir_e+m+"_eXY_"+w+".tif"

                    # Read in all three components of the strain rate
                    dataset = rio.open(eXX_file_e)
                    eXX_e = dataset.read(1)
                    dataset.close()
                    dataset = rio.open(eYY_file_e)
                    eYY_e = dataset.read(1)
                    dataset.close()
                    dataset = rio.open(eXY_file_e)
                    eXY_e = dataset.read(1)
                    dataset.close()

                    # File paths for the appropriate temperature fields, crevassse observations, and test set mask
                    temp_file_w = temp_dir+j+"Training\\Clip_"+j+i+"_250m.tif"
                    temp_file_e = temp_dir+j+"Training\\NE_"+j+i+"_250m.tif"
                    crev_file_w = crev_dir+"Clip_CrevasseMask_250m.tif"
                    crev_file_e = crev_dir+"NE_CrevasseMask_250m.tif"
                    nocrev_file_w = crev_dir+"Clip_NoCrevasseMask_Full_250m.tif"
                    nocrev_file_e = crev_dir+"NE_NoCrevasseMask_250m.tif"
                    test_file_w = test_dir+"W_TestSet_250m.tif"
                    test_file_e = test_dir+"NE_TestSet_250m.tif"
                    
                     # Load data for the west coast temperature field
                    dataset = rio.open(temp_file_w)
                    temp_w = dataset.read(1)
                    dataset.close()
                    # Load crevasse mask for west coast
                    dataset = rio.open(crev_file_w)
                    crevasses_w = dataset.read(1)
                    dataset.close()
                    # Load no crevasse mask for west coast
                    dataset = rio.open(nocrev_file_w)
                    no_crevasses_w = dataset.read(1)
                    dataset.close()
                    # Load test set for west coast
                    dataset = rio.open(test_file_w)
                    test_w = dataset.read(1)
                    dataset.close()

                    # Load data for the east coast temperature field
                    dataset = rio.open(temp_file_e)
                    temp_e = dataset.read(1)
                    dataset.close()
                    # Load crevasse mask for east coast
                    dataset = rio.open(crev_file_e)
                    crevasses_e = dataset.read(1)
                    dataset.close()
                    # Load no crevasse mask for east coast
                    dataset = rio.open(nocrev_file_e)
                    no_crevasses_e = dataset.read(1)
                    dataset.close()
                     # Load test set for east coast
                    dataset = rio.open(test_file_e)
                    test_e = dataset.read(1)
                    dataset.close()

                    # Flatten data from a 2D map into a 1D vector for all datasets, then merge data from east and west training areas 
                    # into a single vector for each variable
                    crevasses_w = np.matrix.flatten(crevasses_w.astype("float64"))
                    crevasses_e = np.matrix.flatten(crevasses_e.astype("float64"))
                    crevasses = np.concatenate((crevasses_w, crevasses_e), axis=0)
                    no_crevasses_w = np.matrix.flatten(no_crevasses_w.astype("float64"))
                    no_crevasses_e = np.matrix.flatten(no_crevasses_e.astype("float64"))
                    no_crevasses = np.concatenate((no_crevasses_w, no_crevasses_e), axis=0)
                    test_w = np.matrix.flatten(test_w.astype("float64"))
                    test_e = np.matrix.flatten(test_e.astype("float64"))
                    test = np.concatenate((test_w, test_e), axis=0)

                    # Combine flattened strain rate matrices for both regions (east and west)
                    eXX_comb = np.concatenate((np.matrix.flatten(eXX_w), np.matrix.flatten(eXX_e)), axis=0)
                    eXY_comb = np.concatenate((np.matrix.flatten(eXY_w), np.matrix.flatten(eXY_e)), axis=0)
                    eYY_comb = np.concatenate((np.matrix.flatten(eYY_w), np.matrix.flatten(eYY_e)), axis=0)

                    # Combine flattened temperature information for both regions (east and west)
                    temp_comb = np.concatenate((np.matrix.flatten(temp_w), np.matrix.flatten(temp_e)), axis=0)

                    # Extract strain rates in crevassed and uncrevassed regions
                    eXX_crev = eXX_comb[crevasses == 1]
                    eXX_nocrev = eXX_comb[no_crevasses == 1]
                    eXY_crev = eXY_comb[crevasses == 1]
                    eXY_nocrev = eXY_comb[no_crevasses == 1]
                    eYY_crev = eYY_comb[crevasses == 1]
                    eYY_nocrev = eYY_comb[no_crevasses == 1]

                    # Extract temperatures for crevassed and uncrevassed regions
                    temp_crev = temp_comb[crevasses == 1]
                    temp_nocrev = temp_comb[no_crevasses == 1]

                    # Extract test set for crevassed and uncrevassed regions
                    test_crev = test[crevasses == 1]
                    test_nocrev = test[no_crevasses == 1]

                    # Merge into a single vectors for all variables of interest
                    eXX = np.concatenate((eXX_crev, eXX_nocrev), axis=0)
                    eXY = np.concatenate((eXY_crev, eXY_nocrev), axis=0)
                    eYY = np.concatenate((eYY_crev, eYY_nocrev), axis=0)
                    temp = np.concatenate((temp_crev,  temp_nocrev), axis=0)
                    test_set = np.concatenate((test_crev,  test_nocrev), axis=0)

                    # Convert temperature field to degrees Kelvin
                    temp = temp + 273.15

                    if k == 0:  # Cuffey & Patterson
                        # Calculate creep coefficient with temperature dependence of activation energy
                        A = np.zeros(temp.shape)
                        for p in range(0,temp.shape[0]):
                            if temp[p] > 273.15:
                                temp[p] = 273.15
                                A[p] = A_star*np.exp((-Qc2/R)*((1/temp[p]) - (1/T_start)))
                            elif temp[p] > 263.0:
                                A[p] = A_star*np.exp((-Qc2/R)*((1/temp[p]) - (1/T_start)))
                            else:
                                A[p] = A_star*np.exp((-Qc/R)*((1/temp[p]) - (1/T_start)))
                        # Convert strain rates from 1/yr to 1/s
                        eXX_s = eXX*(1/(60*60*24*365))
                        eXY_s = eXY*(1/(60*60*24*365))
                        eYY_s = eYY*(1/(60*60*24*365))
                        #Calculate effective stress
                        eE = np.sqrt(0.5*(eXX_s**2 + eYY_s**2 + (-eXX_s - eYY_s)**2) + eXY_s**2)
                        # Calculate deviatoric stress at surface
                        tau_xx = (A**(-1/n))*(eE**((1-n)/n))*eXX_s
                        tau_yy = (A**(-1/n))*(eE**((1-n)/n))*eYY_s
                        tau_xy = (A**(-1/n))*(eE**((1-n)/n))*eXY_s  
                    elif k == 1:    # Hooke
                        B = np.zeros(temp.shape)
                        for p in range(0,temp.shape[0]):
                                if temp[p] > 273.15:
                                    temp[p] = 273.15
                                B[p] = B0*np.exp((T0/temp[p]) - (C/np.power(T_r - temp[p], k)))
                        #Calculate effective stress
                        eE = np.sqrt(0.5*(eXX**2 + eYY**2 + (-eXX - eYY)**2) + eXY**2)
                        # Calculate deviatoric stress at surface
                        tau_xx = B*(eE**((1-n)/n))*eXX
                        tau_yy = B*(eE**((1-n)/n))*eYY
                        tau_xy = B*(eE**((1-n)/n))*eXY

                    # Calculate full Cauchy stress at surface
                    sigma_xx = 2.*tau_xx + tau_yy
                    sigma_yy = 2.*tau_yy + tau_xx

                    # Calculate principal stresses
                    sigma1 = 0.5*(sigma_xx + sigma_yy) + np.sqrt((0.5*(sigma_xx - sigma_yy))**2 + tau_xy**2)
                    sigma2 = 0.5*(sigma_xx + sigma_yy) - np.sqrt((0.5*(sigma_xx - sigma_yy))**2 + tau_xy**2)

                    # Von Mises Stress over whole area of interest
                    sigmaV = np.sqrt(sigma1**2 - sigma1*sigma2 + sigma2**2)
        
                    # Make the label set
                    label = np.concatenate((np.ones(temp_crev.shape), np.zeros(temp_nocrev.shape)), axis=0)

                    # Remove regions of pure compression, because we will automatically predict no fracture there
                    stress = sigmaV[sigma1 > 0.]
                    test_set = test_set[sigma1 > 0.]
                    compression_label = label[sigma1 <= 0.]
                    label = label[sigma1 > 0.]

                    # Test-train split, based on pre-defined test regions
                    stress_train,stress_test,label_train,label_test=train_test_split(stress.reshape(-1,1),label,stratify=test_set)

                    # Instantiate and train the model
                    regress = LogisticRegression(class_weight="balanced")
                    regress.fit(stress_train,label_train)

                    a = temp_maps.index(i)
                    b = temp_model.index(j)
                    c = viscosity.index(k)
                    d = strain_experiments.index(m)
                    e = correlation.index(w)

                    print(i,"-",j,"-",k,"-",m,"-",w)

                    # Calculate the optimal discrimination threshold on the test set
                    prob = regress.predict_proba(stress_train)
                    precision, recall, thresholds = metrics.precision_recall_curve(label_train, prob[:,1])
                    # convert to f score
                    fscore = (2 * precision * recall) / (precision + recall)
                    fscore[np.isnan(fscore)] = 0
                    # locate the index of the largest f score
                    ix = np.argmax(fscore)
                    print('Best Threshold=%.3f' % (thresholds[ix]))

                    threshold_err[a,b,c,d,e] = thresholds[ix]

                    # Calculate crevasse predictions on test set with optimized discrimination threshold
                    prob = regress.predict_proba(stress_test)
                    y_hat = np.zeros(prob[:,1].shape)
                    y_hat[prob[:,1] >= thresholds[ix]] = 1
                    # Reincorporate regions of pure compression which we automatically assign to be no crevasse
                    y_hat = np.concatenate((y_hat, np.zeros(compression_label.shape)), axis=0)
                    y_test = np.concatenate((label_test, compression_label), axis=0)
                    fscore = metrics.f1_score(y_test, y_hat, average="weighted")
                    print('F-Score=%.3f' % (fscore))

                    # Save the f1 score
                    f1_err[a,b,c,d,e] = fscore

                    # Generate and save the probability as a function of stress curve for this model
                    probability = regress.predict_proba(axis)
                    prob_curve_err[:,count] = probability[:,1]
                    ind = np.argmin(np.abs(probability[:,1] - thresholds[ix]))
                    tensile_strength_err[a,b,c,d,e] = axis[ind,0]
                    print("Tensile Strength: "+str(axis[ind,0]/1000.)+" kPa")
        
                    count = count + 1
# Out:
# Annual - RACMO - 0 - Exp0 - Gaussian
# Best Threshold=0.343
# F-Score=0.830
# Tensile Strength: 110.4 kPa
# Annual - RACMO - 0 - Exp0 - Exponential
# Best Threshold=0.364
# F-Score=0.827
# Tensile Strength: 112.9 kPa
# Annual - RACMO - 0 - Exp1 - Gaussian
# Best Threshold=0.341
# F-Score=0.828
# Tensile Strength: 110.4 kPa
# Annual - RACMO - 0 - Exp1 - Exponential
# Best Threshold=0.350
# F-Score=0.824
# Tensile Strength: 111.0 kPa
# Annual - RACMO - 0 - Exp2 - Gaussian
# Best Threshold=0.356
# F-Score=0.831
# Tensile Strength: 112.0 kPa
# Annual - RACMO - 0 - Exp2 - Exponential
# Best Threshold=0.365
# F-Score=0.832
# Tensile Strength: 113.0 kPa
# Annual - RACMO - 0 - Exp3 - Gaussian
# Best Threshold=0.363
# F-Score=0.832
# Tensile Strength: 112.6 kPa
# Annual - RACMO - 0 - Exp3 - Exponential
# Best Threshold=0.348
# F-Score=0.828
# Tensile Strength: 110.9 kPa
# Annual - RACMO - 0 - Exp4 - Gaussian
# Best Threshold=0.355
# F-Score=0.830
# Tensile Strength: 111.7 kPa
# Annual - RACMO - 0 - Exp4 - Exponential
# Best Threshold=0.351
# F-Score=0.827
# Tensile Strength: 111.4 kPa
# Annual - RACMO - 0 - Exp5 - Gaussian
# Best Threshold=0.357
# F-Score=0.828
# Tensile Strength: 112.0 kPa
# Annual - RACMO - 0 - Exp5 - Exponential
# Best Threshold=0.348
# F-Score=0.826
# Tensile Strength: 111.0 kPa
# Annual - RACMO - 0 - Exp6 - Gaussian
# Best Threshold=0.347
# F-Score=0.826
# Tensile Strength: 110.6 kPa
# Annual - RACMO - 0 - Exp6 - Exponential
# Best Threshold=0.341
# F-Score=0.827
# Tensile Strength: 110.1 kPa
# Annual - RACMO - 0 - Exp7 - Gaussian
# Best Threshold=0.347
# F-Score=0.828
# Tensile Strength: 110.9 kPa
# Annual - RACMO - 0 - Exp7 - Exponential
# Best Threshold=0.347
# F-Score=0.829
# Tensile Strength: 111.0 kPa
# Annual - RACMO - 0 - Exp8 - Gaussian
# Best Threshold=0.356
# F-Score=0.830
# Tensile Strength: 111.8 kPa
# Annual - RACMO - 0 - Exp8 - Exponential
# Best Threshold=0.353
# F-Score=0.829
# Tensile Strength: 111.6 kPa
# Annual - RACMO - 0 - Exp9 - Gaussian
# Best Threshold=0.352
# F-Score=0.829
# Tensile Strength: 111.4 kPa
# Annual - RACMO - 0 - Exp9 - Exponential
# Best Threshold=0.355
# F-Score=0.827
# Tensile Strength: 111.6 kPa
# Annual - RACMO - 1 - Exp0 - Gaussian
# Best Threshold=0.351
# F-Score=0.830
# Tensile Strength: 94.8 kPa
# Annual - RACMO - 1 - Exp0 - Exponential
# Best Threshold=0.349
# F-Score=0.826
# Tensile Strength: 94.8 kPa
# Annual - RACMO - 1 - Exp1 - Gaussian
# Best Threshold=0.343
# F-Score=0.828
# Tensile Strength: 94.3 kPa
# Annual - RACMO - 1 - Exp1 - Exponential
# Best Threshold=0.342
# F-Score=0.824
# Tensile Strength: 93.7 kPa
# Annual - RACMO - 1 - Exp2 - Gaussian
# Best Threshold=0.352
# F-Score=0.826
# Tensile Strength: 95.0 kPa
# Annual - RACMO - 1 - Exp2 - Exponential
# Best Threshold=0.345
# F-Score=0.830
# Tensile Strength: 94.5 kPa
# Annual - RACMO - 1 - Exp3 - Gaussian
# Best Threshold=0.346
# F-Score=0.828
# Tensile Strength: 94.6 kPa
# Annual - RACMO - 1 - Exp3 - Exponential
# Best Threshold=0.346
# F-Score=0.826
# Tensile Strength: 94.3 kPa
# Annual - RACMO - 1 - Exp4 - Gaussian
# Best Threshold=0.351
# F-Score=0.830
# Tensile Strength: 94.7 kPa
# Annual - RACMO - 1 - Exp4 - Exponential
# Best Threshold=0.340
# F-Score=0.828
# Tensile Strength: 93.9 kPa
# Annual - RACMO - 1 - Exp5 - Gaussian
# Best Threshold=0.347
# F-Score=0.824
# Tensile Strength: 94.4 kPa
# Annual - RACMO - 1 - Exp5 - Exponential
# Best Threshold=0.341
# F-Score=0.824
# Tensile Strength: 93.9 kPa
# Annual - RACMO - 1 - Exp6 - Gaussian
# Best Threshold=0.342
# F-Score=0.825
# Tensile Strength: 93.9 kPa
# Annual - RACMO - 1 - Exp6 - Exponential
# Best Threshold=0.340
# F-Score=0.825
# Tensile Strength: 93.6 kPa
# Annual - RACMO - 1 - Exp7 - Gaussian
# Best Threshold=0.335
# F-Score=0.828
# Tensile Strength: 93.3 kPa
# Annual - RACMO - 1 - Exp7 - Exponential
# Best Threshold=0.346
# F-Score=0.827
# Tensile Strength: 94.6 kPa
# Annual - RACMO - 1 - Exp8 - Gaussian
# Best Threshold=0.349
# F-Score=0.828
# Tensile Strength: 94.5 kPa
# Annual - RACMO - 1 - Exp8 - Exponential
# Best Threshold=0.343
# F-Score=0.826
# Tensile Strength: 94.1 kPa
# Annual - RACMO - 1 - Exp9 - Gaussian
# Best Threshold=0.342
# F-Score=0.830
# Tensile Strength: 93.9 kPa
# Annual - RACMO - 1 - Exp9 - Exponential
# Best Threshold=0.362
# F-Score=0.826
# Tensile Strength: 95.8 kPa
# Annual - MAR - 0 - Exp0 - Gaussian
# Best Threshold=0.337
# F-Score=0.828
# Tensile Strength: 110.0 kPa
# Annual - MAR - 0 - Exp0 - Exponential
# Best Threshold=0.351
# F-Score=0.825
# Tensile Strength: 111.8 kPa
# Annual - MAR - 0 - Exp1 - Gaussian
# Best Threshold=0.350
# F-Score=0.830
# Tensile Strength: 111.6 kPa
# Annual - MAR - 0 - Exp1 - Exponential
# Best Threshold=0.349
# F-Score=0.827
# Tensile Strength: 111.2 kPa
# Annual - MAR - 0 - Exp2 - Gaussian
# Best Threshold=0.352
# F-Score=0.831
# Tensile Strength: 111.7 kPa
# Annual - MAR - 0 - Exp2 - Exponential
# Best Threshold=0.366
# F-Score=0.833
# Tensile Strength: 113.4 kPa
# Annual - MAR - 0 - Exp3 - Gaussian
# Best Threshold=0.366
# F-Score=0.831
# Tensile Strength: 113.2 kPa
# Annual - MAR - 0 - Exp3 - Exponential
# Best Threshold=0.354
# F-Score=0.828
# Tensile Strength: 111.8 kPa
# Annual - MAR - 0 - Exp4 - Gaussian
# Best Threshold=0.353
# F-Score=0.830
# Tensile Strength: 111.7 kPa
# Annual - MAR - 0 - Exp4 - Exponential
# Best Threshold=0.351
# F-Score=0.826
# Tensile Strength: 111.4 kPa
# Annual - MAR - 0 - Exp5 - Gaussian
# Best Threshold=0.353
# F-Score=0.828
# Tensile Strength: 111.6 kPa
# Annual - MAR - 0 - Exp5 - Exponential
# Best Threshold=0.345
# F-Score=0.825
# Tensile Strength: 110.7 kPa
# Annual - MAR - 0 - Exp6 - Gaussian
# Best Threshold=0.355
# F-Score=0.826
# Tensile Strength: 111.7 kPa
# Annual - MAR - 0 - Exp6 - Exponential
# Best Threshold=0.344
# F-Score=0.824
# Tensile Strength: 110.6 kPa
# Annual - MAR - 0 - Exp7 - Gaussian
# Best Threshold=0.351
# F-Score=0.828
# Tensile Strength: 111.7 kPa
# Annual - MAR - 0 - Exp7 - Exponential
# Best Threshold=0.353
# F-Score=0.830
# Tensile Strength: 111.9 kPa
# Annual - MAR - 0 - Exp8 - Gaussian
# Best Threshold=0.365
# F-Score=0.829
# Tensile Strength: 112.8 kPa
# Annual - MAR - 0 - Exp8 - Exponential
# Best Threshold=0.350
# F-Score=0.829
# Tensile Strength: 111.5 kPa
# Annual - MAR - 0 - Exp9 - Gaussian
# Best Threshold=0.359
# F-Score=0.830
# Tensile Strength: 112.2 kPa
# Annual - MAR - 0 - Exp9 - Exponential
# Best Threshold=0.362
# F-Score=0.828
# Tensile Strength: 112.7 kPa
# Annual - MAR - 1 - Exp0 - Gaussian
# Best Threshold=0.342
# F-Score=0.830
# Tensile Strength: 94.2 kPa
# Annual - MAR - 1 - Exp0 - Exponential
# Best Threshold=0.346
# F-Score=0.823
# Tensile Strength: 94.8 kPa
# Annual - MAR - 1 - Exp1 - Gaussian
# Best Threshold=0.345
# F-Score=0.826
# Tensile Strength: 94.7 kPa
# Annual - MAR - 1 - Exp1 - Exponential
# Best Threshold=0.342
# F-Score=0.821
# Tensile Strength: 94.1 kPa
# Annual - MAR - 1 - Exp2 - Gaussian
# Best Threshold=0.345
# F-Score=0.829
# Tensile Strength: 94.6 kPa
# Annual - MAR - 1 - Exp2 - Exponential
# Best Threshold=0.350
# F-Score=0.828
# Tensile Strength: 95.3 kPa
# Annual - MAR - 1 - Exp3 - Gaussian
# Best Threshold=0.351
# F-Score=0.827
# Tensile Strength: 95.3 kPa
# Annual - MAR - 1 - Exp3 - Exponential
# Best Threshold=0.353
# F-Score=0.826
# Tensile Strength: 95.2 kPa
# Annual - MAR - 1 - Exp4 - Gaussian
# Best Threshold=0.353
# F-Score=0.828
# Tensile Strength: 95.3 kPa
# Annual - MAR - 1 - Exp4 - Exponential
# Best Threshold=0.342
# F-Score=0.826
# Tensile Strength: 94.3 kPa
# Annual - MAR - 1 - Exp5 - Gaussian
# Best Threshold=0.343
# F-Score=0.826
# Tensile Strength: 94.3 kPa
# Annual - MAR - 1 - Exp5 - Exponential
# Best Threshold=0.336
# F-Score=0.822
# Tensile Strength: 93.7 kPa
# Annual - MAR - 1 - Exp6 - Gaussian
# Best Threshold=0.352
# F-Score=0.824
# Tensile Strength: 94.9 kPa
# Annual - MAR - 1 - Exp6 - Exponential
# Best Threshold=0.334
# F-Score=0.826
# Tensile Strength: 93.4 kPa
# Annual - MAR - 1 - Exp7 - Gaussian
# Best Threshold=0.336
# F-Score=0.826
# Tensile Strength: 93.8 kPa
# Annual - MAR - 1 - Exp7 - Exponential
# Best Threshold=0.348
# F-Score=0.829
# Tensile Strength: 95.0 kPa
# Annual - MAR - 1 - Exp8 - Gaussian
# Best Threshold=0.352
# F-Score=0.828
# Tensile Strength: 95.1 kPa
# Annual - MAR - 1 - Exp8 - Exponential
# Best Threshold=0.352
# F-Score=0.827
# Tensile Strength: 95.2 kPa
# Annual - MAR - 1 - Exp9 - Gaussian
# Best Threshold=0.353
# F-Score=0.831
# Tensile Strength: 95.1 kPa
# Annual - MAR - 1 - Exp9 - Exponential
# Best Threshold=0.353
# F-Score=0.824
# Tensile Strength: 95.3 kPa
# Annual - CARRA - 0 - Exp0 - Gaussian
# Best Threshold=0.338
# F-Score=0.830
# Tensile Strength: 115.8 kPa
# Annual - CARRA - 0 - Exp0 - Exponential
# Best Threshold=0.358
# F-Score=0.826
# Tensile Strength: 118.1 kPa
# Annual - CARRA - 0 - Exp1 - Gaussian
# Best Threshold=0.338
# F-Score=0.826
# Tensile Strength: 116.0 kPa
# Annual - CARRA - 0 - Exp1 - Exponential
# Best Threshold=0.347
# F-Score=0.826
# Tensile Strength: 116.6 kPa
# Annual - CARRA - 0 - Exp2 - Gaussian
# Best Threshold=0.370
# F-Score=0.830
# Tensile Strength: 119.4 kPa
# Annual - CARRA - 0 - Exp2 - Exponential
# Best Threshold=0.365
# F-Score=0.832
# Tensile Strength: 119.0 kPa
# Annual - CARRA - 0 - Exp3 - Gaussian
# Best Threshold=0.359
# F-Score=0.831
# Tensile Strength: 118.2 kPa
# Annual - CARRA - 0 - Exp3 - Exponential
# Best Threshold=0.360
# F-Score=0.828
# Tensile Strength: 118.2 kPa
# Annual - CARRA - 0 - Exp4 - Gaussian
# Best Threshold=0.347
# F-Score=0.829
# Tensile Strength: 116.8 kPa
# Annual - CARRA - 0 - Exp4 - Exponential
# Best Threshold=0.345
# F-Score=0.828
# Tensile Strength: 116.6 kPa
# Annual - CARRA - 0 - Exp5 - Gaussian
# Best Threshold=0.356
# F-Score=0.827
# Tensile Strength: 117.6 kPa
# Annual - CARRA - 0 - Exp5 - Exponential
# Best Threshold=0.353
# F-Score=0.824
# Tensile Strength: 117.5 kPa
# Annual - CARRA - 0 - Exp6 - Gaussian
# Best Threshold=0.359
# F-Score=0.825
# Tensile Strength: 117.9 kPa
# Annual - CARRA - 0 - Exp6 - Exponential
# Best Threshold=0.356
# F-Score=0.828
# Tensile Strength: 117.6 kPa
# Annual - CARRA - 0 - Exp7 - Gaussian
# Best Threshold=0.358
# F-Score=0.829
# Tensile Strength: 118.0 kPa
# Annual - CARRA - 0 - Exp7 - Exponential
# Best Threshold=0.338
# F-Score=0.829
# Tensile Strength: 116.0 kPa
# Annual - CARRA - 0 - Exp8 - Gaussian
# Best Threshold=0.344
# F-Score=0.829
# Tensile Strength: 116.3 kPa
# Annual - CARRA - 0 - Exp8 - Exponential
# Best Threshold=0.347
# F-Score=0.828
# Tensile Strength: 116.9 kPa
# Annual - CARRA - 0 - Exp9 - Gaussian
# Best Threshold=0.355
# F-Score=0.828
# Tensile Strength: 117.3 kPa
# Annual - CARRA - 0 - Exp9 - Exponential
# Best Threshold=0.354
# F-Score=0.828
# Tensile Strength: 117.5 kPa
# Annual - CARRA - 1 - Exp0 - Gaussian
# Best Threshold=0.350
# F-Score=0.830
# Tensile Strength: 101.3 kPa
# Annual - CARRA - 1 - Exp0 - Exponential
# Best Threshold=0.358
# F-Score=0.824
# Tensile Strength: 102.4 kPa
# Annual - CARRA - 1 - Exp1 - Gaussian
# Best Threshold=0.333
# F-Score=0.826
# Tensile Strength: 100.1 kPa
# Annual - CARRA - 1 - Exp1 - Exponential
# Best Threshold=0.345
# F-Score=0.826
# Tensile Strength: 100.7 kPa
# Annual - CARRA - 1 - Exp2 - Gaussian
# Best Threshold=0.360
# F-Score=0.831
# Tensile Strength: 102.4 kPa
# Annual - CARRA - 1 - Exp2 - Exponential
# Best Threshold=0.359
# F-Score=0.830
# Tensile Strength: 102.5 kPa
# Annual - CARRA - 1 - Exp3 - Gaussian
# Best Threshold=0.362
# F-Score=0.829
# Tensile Strength: 102.6 kPa
# Annual - CARRA - 1 - Exp3 - Exponential
# Best Threshold=0.360
# F-Score=0.827
# Tensile Strength: 102.3 kPa
# Annual - CARRA - 1 - Exp4 - Gaussian
# Best Threshold=0.352
# F-Score=0.828
# Tensile Strength: 101.6 kPa
# Annual - CARRA - 1 - Exp4 - Exponential
# Best Threshold=0.357
# F-Score=0.827
# Tensile Strength: 102.0 kPa
# Annual - CARRA - 1 - Exp5 - Gaussian
# Best Threshold=0.359
# F-Score=0.829
# Tensile Strength: 102.2 kPa
# Annual - CARRA - 1 - Exp5 - Exponential
# Best Threshold=0.352
# F-Score=0.823
# Tensile Strength: 101.7 kPa
# Annual - CARRA - 1 - Exp6 - Gaussian
# Best Threshold=0.349
# F-Score=0.823
# Tensile Strength: 101.1 kPa
# Annual - CARRA - 1 - Exp6 - Exponential
# Best Threshold=0.349
# F-Score=0.825
# Tensile Strength: 101.1 kPa
# Annual - CARRA - 1 - Exp7 - Gaussian
# Best Threshold=0.355
# F-Score=0.827
# Tensile Strength: 102.0 kPa
# Annual - CARRA - 1 - Exp7 - Exponential
# Best Threshold=0.337
# F-Score=0.826
# Tensile Strength: 100.4 kPa
# Annual - CARRA - 1 - Exp8 - Gaussian
# Best Threshold=0.375
# F-Score=0.829
# Tensile Strength: 103.5 kPa
# Annual - CARRA - 1 - Exp8 - Exponential
# Best Threshold=0.353
# F-Score=0.826
# Tensile Strength: 101.6 kPa
# Annual - CARRA - 1 - Exp9 - Gaussian
# Best Threshold=0.361
# F-Score=0.830
# Tensile Strength: 102.3 kPa
# Annual - CARRA - 1 - Exp9 - Exponential
# Best Threshold=0.355
# F-Score=0.825
# Tensile Strength: 101.9 kPa
# DJF - RACMO - 0 - Exp0 - Gaussian
# Best Threshold=0.352
# F-Score=0.831
# Tensile Strength: 166.6 kPa
# DJF - RACMO - 0 - Exp0 - Exponential
# Best Threshold=0.333
# F-Score=0.826
# Tensile Strength: 164.0 kPa
# DJF - RACMO - 0 - Exp1 - Gaussian
# Best Threshold=0.345
# F-Score=0.829
# Tensile Strength: 165.8 kPa
# DJF - RACMO - 0 - Exp1 - Exponential
# Best Threshold=0.336
# F-Score=0.827
# Tensile Strength: 163.8 kPa
# DJF - RACMO - 0 - Exp2 - Gaussian
# Best Threshold=0.347
# F-Score=0.831
# Tensile Strength: 166.0 kPa
# DJF - RACMO - 0 - Exp2 - Exponential
# Best Threshold=0.352
# F-Score=0.832
# Tensile Strength: 167.0 kPa
# DJF - RACMO - 0 - Exp3 - Gaussian
# Best Threshold=0.332
# F-Score=0.831
# Tensile Strength: 163.6 kPa
# DJF - RACMO - 0 - Exp3 - Exponential
# Best Threshold=0.337
# F-Score=0.828
# Tensile Strength: 164.1 kPa
# DJF - RACMO - 0 - Exp4 - Gaussian
# Best Threshold=0.347
# F-Score=0.831
# Tensile Strength: 165.8 kPa
# DJF - RACMO - 0 - Exp4 - Exponential
# Best Threshold=0.347
# F-Score=0.830
# Tensile Strength: 165.9 kPa
# DJF - RACMO - 0 - Exp5 - Gaussian
# Best Threshold=0.355
# F-Score=0.830
# Tensile Strength: 167.0 kPa
# DJF - RACMO - 0 - Exp5 - Exponential
# Best Threshold=0.352
# F-Score=0.828
# Tensile Strength: 166.5 kPa
# DJF - RACMO - 0 - Exp6 - Gaussian
# Best Threshold=0.349
# F-Score=0.827
# Tensile Strength: 165.6 kPa
# DJF - RACMO - 0 - Exp6 - Exponential
# Best Threshold=0.345
# F-Score=0.829
# Tensile Strength: 165.2 kPa
# DJF - RACMO - 0 - Exp7 - Gaussian
# Best Threshold=0.340
# F-Score=0.827
# Tensile Strength: 165.0 kPa
# DJF - RACMO - 0 - Exp7 - Exponential
# Best Threshold=0.348
# F-Score=0.831
# Tensile Strength: 166.4 kPa
# DJF - RACMO - 0 - Exp8 - Gaussian
# Best Threshold=0.340
# F-Score=0.831
# Tensile Strength: 164.4 kPa
# DJF - RACMO - 0 - Exp8 - Exponential
# Best Threshold=0.343
# F-Score=0.829
# Tensile Strength: 165.1 kPa
# DJF - RACMO - 0 - Exp9 - Gaussian
# Best Threshold=0.341
# F-Score=0.831
# Tensile Strength: 164.6 kPa
# DJF - RACMO - 0 - Exp9 - Exponential
# Best Threshold=0.346
# F-Score=0.830
# Tensile Strength: 165.7 kPa
# DJF - RACMO - 1 - Exp0 - Gaussian
# Best Threshold=0.344
# F-Score=0.831
# Tensile Strength: 160.3 kPa
# DJF - RACMO - 1 - Exp0 - Exponential
# Best Threshold=0.334
# F-Score=0.824
# Tensile Strength: 159.1 kPa
# DJF - RACMO - 1 - Exp1 - Gaussian
# Best Threshold=0.340
# F-Score=0.831
# Tensile Strength: 159.8 kPa
# DJF - RACMO - 1 - Exp1 - Exponential
# Best Threshold=0.342
# F-Score=0.828
# Tensile Strength: 159.5 kPa
# DJF - RACMO - 1 - Exp2 - Gaussian
# Best Threshold=0.341
# F-Score=0.831
# Tensile Strength: 159.9 kPa
# DJF - RACMO - 1 - Exp2 - Exponential
# Best Threshold=0.349
# F-Score=0.831
# Tensile Strength: 161.1 kPa
# DJF - RACMO - 1 - Exp3 - Gaussian
# Best Threshold=0.342
# F-Score=0.830
# Tensile Strength: 160.0 kPa
# DJF - RACMO - 1 - Exp3 - Exponential
# Best Threshold=0.344
# F-Score=0.830
# Tensile Strength: 160.1 kPa
# DJF - RACMO - 1 - Exp4 - Gaussian
# Best Threshold=0.344
# F-Score=0.831
# Tensile Strength: 160.1 kPa
# DJF - RACMO - 1 - Exp4 - Exponential
# Best Threshold=0.334
# F-Score=0.828
# Tensile Strength: 158.6 kPa
# DJF - RACMO - 1 - Exp5 - Gaussian
# Best Threshold=0.344
# F-Score=0.828
# Tensile Strength: 160.2 kPa
# DJF - RACMO - 1 - Exp5 - Exponential
# Best Threshold=0.343
# F-Score=0.826
# Tensile Strength: 159.9 kPa
# DJF - RACMO - 1 - Exp6 - Gaussian
# Best Threshold=0.343
# F-Score=0.825
# Tensile Strength: 159.6 kPa
# DJF - RACMO - 1 - Exp6 - Exponential
# Best Threshold=0.338
# F-Score=0.828
# Tensile Strength: 159.0 kPa
# DJF - RACMO - 1 - Exp7 - Gaussian
# Best Threshold=0.345
# F-Score=0.829
# Tensile Strength: 160.5 kPa
# DJF - RACMO - 1 - Exp7 - Exponential
# Best Threshold=0.332
# F-Score=0.830
# Tensile Strength: 158.6 kPa
# DJF - RACMO - 1 - Exp8 - Gaussian
# Best Threshold=0.338
# F-Score=0.829
# Tensile Strength: 159.1 kPa
# DJF - RACMO - 1 - Exp8 - Exponential
# Best Threshold=0.333
# F-Score=0.825
# Tensile Strength: 158.5 kPa
# DJF - RACMO - 1 - Exp9 - Gaussian
# Best Threshold=0.338
# F-Score=0.829
# Tensile Strength: 158.9 kPa
# DJF - RACMO - 1 - Exp9 - Exponential
# Best Threshold=0.350
# F-Score=0.826
# Tensile Strength: 161.1 kPa
# DJF - MAR - 0 - Exp0 - Gaussian
# Best Threshold=0.342
# F-Score=0.829
# Tensile Strength: 167.9 kPa
# DJF - MAR - 0 - Exp0 - Exponential
# Best Threshold=0.355
# F-Score=0.826
# Tensile Strength: 170.4 kPa
# DJF - MAR - 0 - Exp1 - Gaussian
# Best Threshold=0.341
# F-Score=0.829
# Tensile Strength: 168.0 kPa
# DJF - MAR - 0 - Exp1 - Exponential
# Best Threshold=0.331
# F-Score=0.825
# Tensile Strength: 165.4 kPa
# DJF - MAR - 0 - Exp2 - Gaussian
# Best Threshold=0.365
# F-Score=0.832
# Tensile Strength: 171.4 kPa
# DJF - MAR - 0 - Exp2 - Exponential
# Best Threshold=0.343
# F-Score=0.830
# Tensile Strength: 168.4 kPa
# DJF - MAR - 0 - Exp3 - Gaussian
# Best Threshold=0.348
# F-Score=0.831
# Tensile Strength: 168.9 kPa
# DJF - MAR - 0 - Exp3 - Exponential
# Best Threshold=0.332
# F-Score=0.827
# Tensile Strength: 165.9 kPa
# DJF - MAR - 0 - Exp4 - Gaussian
# Best Threshold=0.335
# F-Score=0.826
# Tensile Strength: 166.5 kPa
# DJF - MAR - 0 - Exp4 - Exponential
# Best Threshold=0.344
# F-Score=0.828
# Tensile Strength: 167.9 kPa
# DJF - MAR - 0 - Exp5 - Gaussian
# Best Threshold=0.351
# F-Score=0.828
# Tensile Strength: 169.1 kPa
# DJF - MAR - 0 - Exp5 - Exponential
# Best Threshold=0.356
# F-Score=0.826
# Tensile Strength: 169.9 kPa
# DJF - MAR - 0 - Exp6 - Gaussian
# Best Threshold=0.337
# F-Score=0.825
# Tensile Strength: 166.7 kPa
# DJF - MAR - 0 - Exp6 - Exponential
# Best Threshold=0.350
# F-Score=0.828
# Tensile Strength: 168.7 kPa
# DJF - MAR - 0 - Exp7 - Gaussian
# Best Threshold=0.352
# F-Score=0.828
# Tensile Strength: 169.6 kPa
# DJF - MAR - 0 - Exp7 - Exponential
# Best Threshold=0.347
# F-Score=0.828
# Tensile Strength: 168.9 kPa
# DJF - MAR - 0 - Exp8 - Gaussian
# Best Threshold=0.354
# F-Score=0.830
# Tensile Strength: 169.6 kPa
# DJF - MAR - 0 - Exp8 - Exponential
# Best Threshold=0.354
# F-Score=0.831
# Tensile Strength: 169.6 kPa
# DJF - MAR - 0 - Exp9 - Gaussian
# Best Threshold=0.333
# F-Score=0.830
# Tensile Strength: 166.2 kPa
# DJF - MAR - 0 - Exp9 - Exponential
# Best Threshold=0.361
# F-Score=0.829
# Tensile Strength: 171.0 kPa
# DJF - MAR - 1 - Exp0 - Gaussian
# Best Threshold=0.338
# F-Score=0.829
# Tensile Strength: 162.6 kPa
# DJF - MAR - 1 - Exp0 - Exponential
# Best Threshold=0.349
# F-Score=0.822
# Tensile Strength: 164.9 kPa
# DJF - MAR - 1 - Exp1 - Gaussian
# Best Threshold=0.331
# F-Score=0.828
# Tensile Strength: 161.9 kPa
# DJF - MAR - 1 - Exp1 - Exponential
# Best Threshold=0.342
# F-Score=0.825
# Tensile Strength: 163.0 kPa
# DJF - MAR - 1 - Exp2 - Gaussian
# Best Threshold=0.349
# F-Score=0.828
# Tensile Strength: 164.8 kPa
# DJF - MAR - 1 - Exp2 - Exponential
# Best Threshold=0.348
# F-Score=0.830
# Tensile Strength: 164.7 kPa
# DJF - MAR - 1 - Exp3 - Gaussian
# Best Threshold=0.353
# F-Score=0.828
# Tensile Strength: 165.1 kPa
# DJF - MAR - 1 - Exp3 - Exponential
# Best Threshold=0.336
# F-Score=0.827
# Tensile Strength: 162.1 kPa
# DJF - MAR - 1 - Exp4 - Gaussian
# Best Threshold=0.349
# F-Score=0.829
# Tensile Strength: 164.3 kPa
# DJF - MAR - 1 - Exp4 - Exponential
# Best Threshold=0.339
# F-Score=0.827
# Tensile Strength: 162.9 kPa
# DJF - MAR - 1 - Exp5 - Gaussian
# Best Threshold=0.343
# F-Score=0.825
# Tensile Strength: 163.3 kPa
# DJF - MAR - 1 - Exp5 - Exponential
# Best Threshold=0.358
# F-Score=0.825
# Tensile Strength: 165.8 kPa
# DJF - MAR - 1 - Exp6 - Gaussian
# Best Threshold=0.349
# F-Score=0.825
# Tensile Strength: 164.0 kPa
# DJF - MAR - 1 - Exp6 - Exponential
# Best Threshold=0.345
# F-Score=0.827
# Tensile Strength: 163.5 kPa
# DJF - MAR - 1 - Exp7 - Gaussian
# Best Threshold=0.347
# F-Score=0.828
# Tensile Strength: 164.3 kPa
# DJF - MAR - 1 - Exp7 - Exponential
# Best Threshold=0.339
# F-Score=0.829
# Tensile Strength: 163.4 kPa
# DJF - MAR - 1 - Exp8 - Gaussian
# Best Threshold=0.343
# F-Score=0.828
# Tensile Strength: 163.2 kPa
# DJF - MAR - 1 - Exp8 - Exponential
# Best Threshold=0.343
# F-Score=0.825
# Tensile Strength: 163.6 kPa
# DJF - MAR - 1 - Exp9 - Gaussian
# Best Threshold=0.345
# F-Score=0.828
# Tensile Strength: 163.5 kPa
# DJF - MAR - 1 - Exp9 - Exponential
# Best Threshold=0.351
# F-Score=0.826
# Tensile Strength: 165.0 kPa
# DJF - CARRA - 0 - Exp0 - Gaussian
# Best Threshold=0.347
# F-Score=0.829
# Tensile Strength: 169.2 kPa
# DJF - CARRA - 0 - Exp0 - Exponential
# Best Threshold=0.362
# F-Score=0.824
# Tensile Strength: 172.1 kPa
# DJF - CARRA - 0 - Exp1 - Gaussian
# Best Threshold=0.345
# F-Score=0.825
# Tensile Strength: 169.7 kPa
# DJF - CARRA - 0 - Exp1 - Exponential
# Best Threshold=0.340
# F-Score=0.823
# Tensile Strength: 168.0 kPa
# DJF - CARRA - 0 - Exp2 - Gaussian
# Best Threshold=0.360
# F-Score=0.830
# Tensile Strength: 171.7 kPa
# DJF - CARRA - 0 - Exp2 - Exponential
# Best Threshold=0.366
# F-Score=0.829
# Tensile Strength: 172.7 kPa
# DJF - CARRA - 0 - Exp3 - Gaussian
# Best Threshold=0.350
# F-Score=0.831
# Tensile Strength: 170.2 kPa
# DJF - CARRA - 0 - Exp3 - Exponential
# Best Threshold=0.347
# F-Score=0.828
# Tensile Strength: 169.3 kPa
# DJF - CARRA - 0 - Exp4 - Gaussian
# Best Threshold=0.357
# F-Score=0.827
# Tensile Strength: 170.9 kPa
# DJF - CARRA - 0 - Exp4 - Exponential
# Best Threshold=0.342
# F-Score=0.826
# Tensile Strength: 168.6 kPa
# DJF - CARRA - 0 - Exp5 - Gaussian
# Best Threshold=0.368
# F-Score=0.828
# Tensile Strength: 172.6 kPa
# DJF - CARRA - 0 - Exp5 - Exponential
# Best Threshold=0.369
# F-Score=0.824
# Tensile Strength: 172.8 kPa
# DJF - CARRA - 0 - Exp6 - Gaussian
# Best Threshold=0.366
# F-Score=0.824
# Tensile Strength: 172.0 kPa
# DJF - CARRA - 0 - Exp6 - Exponential
# Best Threshold=0.356
# F-Score=0.826
# Tensile Strength: 170.7 kPa
# DJF - CARRA - 0 - Exp7 - Gaussian
# Best Threshold=0.366
# F-Score=0.827
# Tensile Strength: 172.5 kPa
# DJF - CARRA - 0 - Exp7 - Exponential
# Best Threshold=0.354
# F-Score=0.827
# Tensile Strength: 170.9 kPa
# DJF - CARRA - 0 - Exp8 - Gaussian
# Best Threshold=0.351
# F-Score=0.826
# Tensile Strength: 170.0 kPa
# DJF - CARRA - 0 - Exp8 - Exponential
# Best Threshold=0.339
# F-Score=0.825
# Tensile Strength: 168.4 kPa
# DJF - CARRA - 0 - Exp9 - Gaussian
# Best Threshold=0.351
# F-Score=0.829
# Tensile Strength: 169.9 kPa
# DJF - CARRA - 0 - Exp9 - Exponential
# Best Threshold=0.346
# F-Score=0.825
# Tensile Strength: 169.3 kPa
# DJF - CARRA - 1 - Exp0 - Gaussian
# Best Threshold=0.348
# F-Score=0.827
# Tensile Strength: 165.3 kPa
# DJF - CARRA - 1 - Exp0 - Exponential
# Best Threshold=0.372
# F-Score=0.823
# Tensile Strength: 169.4 kPa
# DJF - CARRA - 1 - Exp1 - Gaussian
# Best Threshold=0.337
# F-Score=0.824
# Tensile Strength: 164.1 kPa
# DJF - CARRA - 1 - Exp1 - Exponential
# Best Threshold=0.348
# F-Score=0.822
# Tensile Strength: 165.2 kPa
# DJF - CARRA - 1 - Exp2 - Gaussian
# Best Threshold=0.361
# F-Score=0.829
# Tensile Strength: 167.5 kPa
# DJF - CARRA - 1 - Exp2 - Exponential
# Best Threshold=0.358
# F-Score=0.826
# Tensile Strength: 167.5 kPa
# DJF - CARRA - 1 - Exp3 - Gaussian
# Best Threshold=0.356
# F-Score=0.829
# Tensile Strength: 166.6 kPa
# DJF - CARRA - 1 - Exp3 - Exponential
# Best Threshold=0.360
# F-Score=0.823
# Tensile Strength: 167.1 kPa
# DJF - CARRA - 1 - Exp4 - Gaussian
# Best Threshold=0.350
# F-Score=0.827
# Tensile Strength: 165.8 kPa
# DJF - CARRA - 1 - Exp4 - Exponential
# Best Threshold=0.337
# F-Score=0.823
# Tensile Strength: 163.8 kPa
# DJF - CARRA - 1 - Exp5 - Gaussian
# Best Threshold=0.374
# F-Score=0.825
# Tensile Strength: 169.2 kPa
# DJF - CARRA - 1 - Exp5 - Exponential
# Best Threshold=0.361
# F-Score=0.821
# Tensile Strength: 167.4 kPa
# DJF - CARRA - 1 - Exp6 - Gaussian
# Best Threshold=0.337
# F-Score=0.820
# Tensile Strength: 163.4 kPa
# DJF - CARRA - 1 - Exp6 - Exponential
# Best Threshold=0.339
# F-Score=0.824
# Tensile Strength: 163.8 kPa
# DJF - CARRA - 1 - Exp7 - Gaussian
# Best Threshold=0.344
# F-Score=0.826
# Tensile Strength: 165.0 kPa
# DJF - CARRA - 1 - Exp7 - Exponential
# Best Threshold=0.349
# F-Score=0.827
# Tensile Strength: 165.9 kPa
# DJF - CARRA - 1 - Exp8 - Gaussian
# Best Threshold=0.348
# F-Score=0.827
# Tensile Strength: 165.4 kPa
# DJF - CARRA - 1 - Exp8 - Exponential
# Best Threshold=0.343
# F-Score=0.826
# Tensile Strength: 164.6 kPa
# DJF - CARRA - 1 - Exp9 - Gaussian
# Best Threshold=0.350
# F-Score=0.827
# Tensile Strength: 165.4 kPa
# DJF - CARRA - 1 - Exp9 - Exponential
# Best Threshold=0.354
# F-Score=0.825
# Tensile Strength: 166.4 kPa

# %% [markdown]
# ## [3] Save Tensile Strength Results
#
# Save both the baseline results without velocity perturbations and the models that quantify the impact of velocity uncertainty in a pickle file as a dictionary.

# %%
# base_curves - baseline fracture/no fracture probability curves for each experiment
# base_thresh - baseline probability threshold for fracture discrimination for each experiment
# base_ts - baseline tensile strength for each experiment
# err_curves - fracture/no fracture probability curves for all 120 models that use perturbed velocity maps
# err_thresh - probability threshold for fracture discrimination for each of the 120 models from the perturbed velocity ensemble
# err_ts - tensile strength estimates for each of the 120 models from the perturbed velocity ensemble
# err_f1 - F1 score on test set for each of the 120 models from the perturbed velocity ensemble

results = {"base_curves": prob_curve, "base_thresh": threshold, "base_ts": tensile_strength, 
           "err_curves": prob_curve_err, "err_thresh": threshold_err, "err_ts": tensile_strength_err, "err_f1": f1_err}

with open('TensileStrengthResults_Final.pickle', 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Plot Final Tensile Strength Comparison Plot
#
# Code to reproduce Figure 4 in the main text.

# %%
###### Make the nice plots

import pickle
with open('data/TensileStrengthResults_Final.pickle', 'rb') as f:
    results = pickle.load(f)

axis = np.arange(0,350000,100).reshape(-1,1)
new_ax = np.ndarray.flatten(axis)

prob_curve_err = results['err_curves']

plt.close("all")
fig, ax = plt.subplots(layout="constrained", figsize=(6.5,3.5))
# Plot grey patches showing fractured zones
ax.fill_between(np.ndarray.flatten(axis)/1000, np.max(np.ndarray.flatten(results['base_thresh']))*np.ones(new_ax.shape), np.ones(new_ax.shape), 
                color="#BFBFBF", alpha=0.5)
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(np.ndarray.flatten(results['base_thresh']))*np.ones(new_ax.shape),  
                np.max(np.ndarray.flatten(results['base_thresh']))*np.ones(new_ax.shape), color="#D7D7D7", alpha=0.5)
# Plot individual fracture probaiblity curves with their width set by the range of solutions given different velocity perturbations
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,0:19],axis=1), np.max(prob_curve_err[:,0:19],axis=1), color="#551d4e")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,20:39],axis=1), np.max(prob_curve_err[:,20:39],axis=1), color="#ba40ab")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,40:59],axis=1), np.max(prob_curve_err[:,40:59],axis=1),color="#cd1c4d")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,60:79],axis=1), np.max(prob_curve_err[:,60:79],axis=1), color="#eb6b90")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,80:99],axis=1), np.max(prob_curve_err[:,80:99],axis=1), color="#f5936a")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,100:119],axis=1), np.max(prob_curve_err[:,100:119],axis=1), color="#f9baa1")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,120:139],axis=1), np.max(prob_curve_err[:,120:139],axis=1), color="#3f3872")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,140:159],axis=1), np.max(prob_curve_err[:,140:159],axis=1), color="#7b72ba")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,160:179],axis=1), np.max(prob_curve_err[:,160:179],axis=1), color="#3487a5")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,180:199],axis=1), np.max(prob_curve_err[:,180:199],axis=1), color="#79bbd5")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,200:219],axis=1), np.max(prob_curve_err[:,200:219],axis=1), color="#43bbad")
ax.fill_between(np.ndarray.flatten(axis)/1000, np.min(prob_curve_err[:,220:239],axis=1), np.max(prob_curve_err[:,220:239],axis=1), color="#97d9d1")
# Plot vertical dashed lines at the minimum and maximum tensile strength estimates
ax.vlines(94.1, np.min(np.ndarray.flatten(results['base_thresh'])), 1., "k", linestyle="dotted", linewidth=1)
ax.vlines(117.3, np.min(np.ndarray.flatten(results['base_thresh'])), 1., "k", linestyle="dotted", linewidth=1)
ax.vlines(159.2, np.min(np.ndarray.flatten(results['base_thresh'])), 1., "k", linestyle="dotted", linewidth=1)
ax.vlines(169.5, np.min(np.ndarray.flatten(results['base_thresh'])), 1., "k", linestyle="dotted", linewidth=1)
# Plot block dots at the baseline tensile strength for each scenario
ax.scatter(np.ndarray.flatten(results['base_ts'])/1000, np.ndarray.flatten(results['base_thresh']), s=5, color="k")
plt.xlabel("von Mises Stress (kPa)", fontname="Arial")
plt.ylabel("Probability of Fracture", fontname="Arial");
plt.xlim((0,350))
plt.ylim((0,1))
for tick in ax.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax.get_yticklabels():
    tick.set_fontname("Arial")
plt.savefig("TensileStrength_v2.svg")
plt.show()
